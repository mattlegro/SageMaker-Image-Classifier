# %% [markdown]
# # This Notebook

# %% [markdown]
# In this notebook we will explore scraping and Fish Species Database creation. From the intro notebook, we are interested in storing information per species on:
#
# 1. Scientific Name, Genus Species ex Holacanthus tricolor (str)
# 2. Fish Family ex Pomacanthidae
# 3. Common Name ex. Rock Beauty (str or list of strs)
# 4. Common Category ex Angelfishes (str)
# 5. range Range ex 12-20 (cm) (tuple of int)
# 6. Depth Occurence ex 3-25 (m) (tuple of int)
# 7. Known Distribution (here the distribution tag from the site could be combined after scraping with the location of the exemplar images and cleaned of vague terms)
# 8. Distinctive Features and Behaviors ex Black Lipstick
#
# We've seen that some of the sites have geotags / coordinates and we could look into creating a map in the future, but for now we will try and create a string list of locations.

# %% [markdown]
# ## Technologies

# %% [markdown]
# To start out with, we will try beautifulsoup4, requests, and eventually the google images API

# %%
import requests
import os
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# # Scraping Sections by Website

# %% [markdown]
# ## [reefguide.org](https://reefguide.org/carib/cat_sci.html)

# %% [markdown]
# So from this site I would like to start from their index page, which conveniently has been demarcated elsewhere to contain only caribbean species. Then, we will need to go through each entry in the index table, enter that page, find and store all the appropriate information as well as download any images. Let's get familiar with BS4 and see what the soup obj and parser looks like.

# %%
URL = 'https://reefguide.org/carib/cat_sci.html'
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Caribbean Reefs - Index of Species by Scientific Names
#   </title>
#   <script src="jquery/js/jquery-1.7.1.min.js" type="text/javascript">
#   </script>
#   <script src="jquery/js/jquery-ui-1.8.16.custom.min.js" type="text/javascript">
#   </script>
#   <script src="js/mainindex.js" type="text/javascript">
#   </script>
#   <link href="jquery/css/ui-lightness/jquery-ui-1.8.16.custom.css" rel="Stylesheet" type="text/css"/>
#   <link href="css/all.css" rel="stylesheet" type="text/css"/>
#   <link href="css/catalog.css" rel="stylesheet" type="text/css"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3281928-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-3281928-1');
#   </script>
#  </head>
#  <body>
#   <script>
#    $(document).ready(SpeciesInit);
#   </script>
#   <div id="maincontainer">
#    <div class="banner1" id="topsection">
#     <h4>
#      Florent's Guide To The
#      <span class="pretitle">
#       Florida, Bahamas &amp;
#      </span>
#     </h4>
#     <h1>
#      Caribbean Reefs
#     </h1>
#     <ul class="topnav">
#      <li class="ba">
#       <a href="../home.html">
#        Home
#       </a>
#      </li>
#      <li>
#       <span class="ba">
#        <a>
#         Area
#        </a>
#       </span>
#       <ul class="subnav">
#        <li>
#         <a href="../carib/index1.html">
#          <div class="ui-icon ui-icon-check arrow">
#          </div>
#          Caribbean
#         </a>
#        </li>
#        <li>
#         <a href="../indopac/index1.html">
#          <div class="arrow2">
#          </div>
#          Pacific
#         </a>
#        </li>
#        <li>
#         <a href="../keys/index1.html">
#          <div class="arrow2">
#          </div>
#          South Florida
#         </a>
#        </li>
#        <li>
#         <a href="../hawaii/index1.html">
#          <div class="arrow2">
#          </div>
#          Hawaii
#         </a>
#        </li>
#        <li>
#         <a href="../index1.html">
#          <div class="arrow2">
#          </div>
#          Worldwide
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <span class="ba">
#        <a>
#         Index
#        </a>
#       </span>
#       <ul class="subnav">
#        <li>
#         <a href="cat.html">
#          By Common Names
#         </a>
#        </li>
#        <li>
#         <a href="cat_grp.html">
#          By Categories
#         </a>
#        </li>
#        <li>
#         <a href="cat_sci.html">
#          By Scientific Names
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="ba">
#       <a href="../latest.html">
#        Updates
#       </a>
#      </li>
#      <li class="ba">
#       <a href="../about.html">
#        About
#       </a>
#      </li>
#      <li class="ba">
#       <a href="http://reefguide.org/reefguide.xml">
#        RSS
#       </a>
#      </li>
#      <li class="ba">
#       <a href="../search.html">
#        Search
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="contentwrapper">
#     <div id="contentcolumnCat">
#      <div class="catType">
#       <a class="catalog" href="cat.html">
#        By Common Name
#       </a>
#       |
#       <a class="catalog" href="cat_grp.html">
#        By Category
#       </a>
#       | By Scientific Names
#      </div>
#      <div style="text-align:right;vertical-align: top">
#       <table border="0px" cellpadding="0" cellspacing="0" style="text-align: left; margin-left:auto; margin-right:auto; vertical-align: top; padding: 15px;">
#        <tr style="vertical-align: top">
#         <td>
#          <div class="bigalpha">
#           A
#          </div>
#          <a class="tocnamesci" href="flatneedle.html">
#           Ablennes hians
#          </a>
#          <br/>
#          <a class="tocnamesci" href="sergeantmajor.html">
#           Abudefduf saxatilis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="nightsergeant.html">
#           taurus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="roughheadblenny.html">
#           Acanthemblemaria aspera
#          </a>
#          <br/>
#          <a class="tocnamesci" href="secretaryblenny.html">
#           maria
#          </a>
#          <br/>
#          <a class="tocnamesci" href="spinyheadblenny.html">
#           spinosa
#          </a>
#          <br/>
#          <a class="tocnamesci" href="chiton.html">
#           Acanthopleura granulata
#          </a>
#          <br/>
#          <a class="tocnamesci" href="honeycomb.html">
#           Acanthostracion polygonius
#          </a>
#          <br/>
#          <a class="tocnamesci" href="scrawledcowfish.html">
#           quadricornis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="surgeonfish.html">
#           Acanthurus bahianus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="doctorfish.html">
#           chirurgus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="bluetang.html">
#           coeruleus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="greenmermaidswineglass.html">
#           Acetabularia caliculus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="whitemermaidswineglass.html">
#           crenulata
#          </a>
#          <br/>
#          <a class="tocnamesci" href="redhairswimmingcrab.html">
#           Achelous ordwayi
#          </a>
#          <br/>
#          <a class="tocnamesci" href="ocellateswimmingcrab.html">
#           sebae
#          </a>
#          <br/>
#          <a class="tocnamesci" href="blotchedswimmingcrab.html">
#           spinimanus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="staghorn.html">
#           Acropora cervicornis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="elkhorncoral.html">
#           palmata
#          </a>
#          <br/>
#          <a class="tocnamesci" href="elegantanemone.html">
#           Actinoporus elongatus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="acyrtusartius.html">
#           Acyrtus artius
#          </a>
#          <br/>
#          <a class="tocnamesci" href="eagleray.html">
#           Aetobatus narinari
#          </a>
#          <br/>
#          <a class="tocnamesci" href="scaledlettucecoral.html">
#           Agaricia agaricites f. danai
#          </a>
#          <br/>
#          <a class="tocnamesci" href="lettucecoral.html">
#           agaricities f.
#          </a>
#          <br/>
#          <a class="tocnamesci" href="purplelettucecoral.html">
#           agaricities f.
#          </a>
#          <br/>
#          <a class="tocnamesci" href="fragilesaucercoral.html">
#           fragilis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="dimpledsheetcoral.html">
#           grahamae
#          </a>
#          <br/>
#          <a class="tocnamesci" href="lowreliefletttuce.html">
#           humilis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="whitestarsheet.html">
#           lamarcki
#          </a>
#          <br/>
#          <a class="tocnamesci" href="thinleaflettuce.html">
#           tenuifolia
#          </a>
#          <br/>
#          <a class="tocnamesci" href="agelascerebrum.html">
#           Agelas cerebrum
#          </a>
#          <br/>
#          <a class="tocnamesci" href
us
#          </a>
#          <br/>
#          <a class="tocnamesci" href="palometa.html">
#           goodei
#          </a>
#          <br/>
#          <a class="tocnamesci" href="trachycarisrugosa.html">
#           Trachycaris rugosa
#          </a>
#          <br/>
#          <a class="tocnamesci" href="bleedingteethbryozoan.html">
#           Trematooecia aviculifera
#          </a>
#          <br/>
#          <a class="tocnamesci" href="westindianmanatee.html">
#           Trichechus manatus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="overgrowingmattunicate.html">
#           Trididemnum solidum
#          </a>
#          <br/>
#          <a class="tocnamesci" href="westindianseaegg.html">
#           Tripneustes ventricosus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="tritoniabayeri.html">
#           Tritonicula bayeri
#          </a>
#          <br/>
#          <a class="tocnamesci" href="orangecupcoral.html">
#           Tubastraea coccinea
#          </a>
#          <br/>
#          <a class="tocnamesci" href="turbinellaangulata.html">
#           Turbinella angulata
#          </a>
#          <br/>
#          <a class="tocnamesci" href="dolphin.html">
#           Tursiops truncatus
#          </a>
#          <br/>
#          <div class="bigalpha">
#           U
#          </div>
#          <a class="tocnamesci" href="mermaidsfan.html">
#           Udotea sp.
#          </a>
#          <br/>
#          <a class="tocnamesci" href="mottledmojarra.html">
#           Ulaema lefroyi
#          </a>
#          <br/>
#          <a class="tocnamesci" href="spongezoanthid.html">
#           Umimayanthus parasiticus
#          </a>
#          <br/>
#          <a class="tocnamesci" href="yellowray.html">
#           Urobatis jamaicensis
#          </a>
#          <br/>
#          <div class="bigalpha">
#           V
#          </div>
#          <a class="tocnamesci" href="seapearls.html">
#           Valonia ventricosa
#          </a>
#          <br/>
#          <a class="tocnamesci" href="nettedbarrel.html">
#           Verongula gigantea
#          </a>
#          <br/>
#          <a class="tocnamesci" href="verongulareiswigi.html">
#           reiswigi
#          </a>
#          <br/>
#          <a class="tocnamesci" href="pittedsponge.html">
#           rigida
#          </a>
#          <br/>
#          <div class="bigalpha">
#           W
#          </div>
#          <a class="tocnamesci" href="pinkbushalga.html">
#           Wrangelia penicillata
#          </a>
#          <br/>
#          <div class="bigalpha">
#           X
#          </div>
#          <a class="tocnamesci" href="sargassumtrigger.html">
#           Xanthichthys ringens
#          </a>
#          <br/>
#          <a class="tocnamesci" href="giantbarrel.html">
#           Xestospongia muta
#          </a>
#          <br/>
#          <a class="tocnamesci" href="xestospongiarosariensis.html">
#           rosariensis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="rosyrazorfish.html">
#           Xyrichtys martinicensis
#          </a>
#          <br/>
#          <a class="tocnamesci" href="pearlyrazorfish.html">
#           novacula
#          </a>
#          <br/>
#          <a class="tocnamesci" href="greenrazor.html">
#           splendens
#          </a>
#          <br/>
#          <div class="bigalpha">
#           Z
#          </div>
#          <a class="tocnamesci" href="matzoanthid.html">
#           Zoanthus pulchellus
#          </a>
#          <br/>
#         </td>
#        </tr>
#       </table>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(soup.get_text())
# Out:
# Caribbean Reefs - Index of Species by Scientific Names
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Florent's Guide To The Florida, Bahamas &
# Caribbean Reefs
#
#
# Home
#
#
# Area
#
#
# Caribbean
#
#
#  Pacific
#
#
#  South Florida
#
#
#  Hawaii
#
#
#  Worldwide
#
#
#
#
# Index
#
#
#  By Common Names
#
#
#  By Categories
#
#
#  By Scientific Names
#
#
#
#
# Updates
#
#
# About
#
#
# RSS
#
#
# Search
#
#
#
#
#
#
# By Common Name | By Category | By Scientific Names
#
#
#
#
#
# duskysquirrel.html
# midnightparrot.html
# blueparrot.html
# rainbowparrot.html
# stripedparrotfish.html
# princessparrot.html
# queenparrot.html
# diskcoral.html
# atlanticmushroomcoral.html
# cero.html
# orangelumpyencrustingsponge.html
# scorpaenaalbifimbria.html
# scorpaenagrandicornis.html
# mushroomscorpionfish.html
# scorpion.html
# reefscorpionfish.html
# spanishlobster.html
# reefsquid.html
# almacojack.html
# lanternbass.html
# serranussubligarius.html
# tobacco.html
# harlequinbass.html
# chalkbass.html
# branchinghydroid.html
# lesserstarletcoral.html
# massivestarlet.html
# variableboring.html
# smenospongiaconulosa.html
# smoothstarcoral.html
# greenblotchparrotfish.html
# redbandparrot.html
# redtailparrot.html
# yellowtailparrot.html
# stoplightparrotfish.html
# loggerheadsponge.html
# bandtailpuffer.html
# checkeredpuffer.html
# barracuda.html
# pinkredencrusting.html
# spirastrellahartmani.html
# spirobranchusgiganteus.html
# thornyoyster.html
# duskydamsel.html
# longfindamselfish.html
# beaugregory.html
# bicolordamsel.html
# threespotdamsel.html
# cocoadamselfish.html
# spinnerdolphin.html
# slenderchiton.html
# coralshrimp.html
# goldencoralshrimp.html
# arrowcrab.html
# blushingstarcoral.html
# sunanemone.html
# wirecoral.html
# strombusalatus.html
# redfinneedlefish.html
# roselace.html
# volcanosponge.html
# channelflounder.html
# symphurusdiomedeanus.html
# encrustingsocialtunicates.html
# sanddiver.html
# bluestripedlizardfish.html
# clubtippedanemone.html
# bluehead.html
# caribbeansquatshrimp.html
# thuridillapicta.html
# algaehydroid.html
# tigrigobiusharveyi.html
# greenbandedgoby.html
# topsentiaophiraphidites.html
# permit.html
# palometa.html
# trachycarisrugosa.html
# bleedingteethbryozoan.html
# westindianmanatee.html
# overgrowingmattunicate.html
# westindianseaegg.html
# tritoniabayeri.html
# orangecupcoral.html
# turbinellaangulata.html
# dolphin.html
# mermaidsfan.html
# mottledmojarra.html
# spongezoanthid.html
# yellowray.html
# seapearls.html
# nettedbarrel.html
# verongulareiswigi.html
# pittedsponge.html
# pinkbushalga.html
# sargassumtrigger.html
# giantbarrel.html
# xestospongiarosariensis.html
# rosyrazorfish.html
# pearlyrazorfish.html
# greenrazor.html
# matzoanthid.html

# %% [markdown]
# Okay so it seems that the href contained in the table entry needs to be appended to https://reefguide.org/carib/ and then we can follow it to the species page. So we will create a cleaned list of all the species from the index page to use for accessing all the pages.

# %%
table_contents = soup.find_all('td')
ref_lst = []
for result in table_contents:
    try:
        species = result.find_all('a')
        for specie in species:
            # print(specie.get('href'))
            ref_lst.append(specie.get('href'))
    except:
        pass

# %%
ref_lst
# Out:
# ['flatneedle.html',
#  'sergeantmajor.html',
#  'nightsergeant.html',
#  'roughheadblenny.html',
#  'secretaryblenny.html',
#  'spinyheadblenny.html',
#  'chiton.html',
#  'honeycomb.html',
#  'scrawledcowfish.html',
#  'surgeonfish.html',
#  'doctorfish.html',
#  'bluetang.html',
#  'greenmermaidswineglass.html',
#  'whitemermaidswineglass.html',
#  'redhairswimmingcrab.html',
#  'ocellateswimmingcrab.html',
#  'blotchedswimmingcrab.html',
#  'staghorn.html',
#  'elkhorncoral.html',
#  'elegantanemone.html',
#  'acyrtusartius.html',
#  'eagleray.html',
#  'scaledlettucecoral.html',
#  'lettucecoral.html',
#  'purplelettucecoral.html',
#  'fragilesaucercoral.html',
#  'dimpledsheetcoral.html',
#  'lowreliefletttuce.html',
#  'whitestarsheet.html',
#  'thinleaflettuce.html',
#  'agelascerebrum.html',
#  'agelascitrina.html',
#  'elephantear.html',
#  'agelasconifera.html',
#  'agelastubulata.html',
#  'brownclusteredtube.html',
#  'branchingtube.html',
#  'bonefish.html',
#  'aligergallus.html',
#  'queenconch.html',
#  'redsnappingshrimp.html',
#  'alpheuspolystictus.html',
#  'scrawledfile.html',
#  'hawkfish.html',
#  'pipehorse.html',
#  'erectropesponge.html',
#  'swimmingcrinoid.html',
#  'featherduster.html',
#  'ghostfeatherduster.html',
#  'pederson.html',
#  'isopod.html',
#  'anisonotuscurvirostris.html',
#  'blackmargate.html',
#  'porkfish.html',
#  'antennariusscaber.html',
#  'slimyseaplume.html',
#  'bipinnateseaplumes.html',
#  'seaplumes.html',
#  'grayseafanblackcoral.html',
#  'antipatheslenta.html',
#  'bushyblackcoral.html',
#  'featherblackcoral.html',
#  'spottedseahare.html',
#  'stovepipe.html',
#  'rowporeropesponge.html',
#  'yellowtube.html',
#  'scatteredporeropesponge.html',
#  'aplysinainsularis.html',
#  'convolutedbarrel.html',
#  'apogonbinotatus.html',
#  'whitestarcardinalfish.html',
#  'flamefish.html',
#  'palecardinalfish.html',
#  'apogonpseudomaculatus.html',
#  'apogonrobinsi.html',
#  'beltedcardinalfish.html',
#  'sheepshead.html',
#  'arctidesguineensis.html',
#  'clathrinacanariensis.html',
#  'greentubetunicate.html',
#  'furrycucumber.html',
#  'blackfincardinalfish.html',
#  'twospinedseastar.html',
#  'giantbasketstar.html',
#  'trumpet.html',
#  'moonjelly.html',
#  'axiopsisserratifrons.html',
#  'queentrigger.html',
#  'corkscrewanemone.html',
#  'largeeyetoadfish.html',
#  'brownspongezoanthid.html',
#  'maroonspongezoanthid.html',
#  'socialfeatherduster.html',
#  'variegatedfeatherduster.html',
#  'spotfinhogfish.html',
#  'spanishhogfish.html',
#  'peacock.html',
#  'eyedflounder.html',
#  'twoclawshrimp.html',
#  'smallmouthgrunt.html',
#  'blackspottedfeather.html',
#  'corkyseafinger.html',
#  'tutlegrassanemone.html',
#  'wartyseaanemone.html',
#  'redwartyseaanemone.html',
#  'joltheadporgy.html',
#  'saucereyeporgy.html',
#  'plumaporgy.html',
#  'calappaflammea.html',
#  'calappasulcata.html',
#  'calappulatortugae.html',
#  'orangeclawhermit.html',
#  'calliactistricolor.html',
#  'ornatebluecrab.html',
#  'bluecrab.html',
#  'lancerdragonet.html',
#  'callyspongiafallax.html',
#  'azurevase.html',
#  'branchingvase.html',
#  'whitespottedfile.html',
#  'orangespottedfile.html',
#  'oceantrigger.html',
#  'sharpnosepuffer.html',
#  'yellowjack.html',
#  'barjack.html',
#  'bluerunner.html',
#  'horseeyejack.html',
#  'blackjack.html',
#  'bullshark.html',
#  'reefshark.html',
#  'loggerheadturtle.html',
#  'whitetelesto.html',
#  'batwingcoralcrab.html',
#  'upsidedownjelly.html',
#  'mangroveupsidedownjelly.html',
#  'kinghelmet.html',
#  'caulerparacemosa.html',
#  'sawbladealga.html',
#  'cherubfish.html',
#  'graysby.html',
#  'coney.html',
#  'cestumveneris.html',
#  'chaenopsislimbaughi.html',
#  'spadefish.html',
#  'foureyebutterflyfish.html',
#  'spotfinbutter.html',
#  'reefbutterflyfish.html',
#  'bandedbutterfly.html',
#  'atlantictritonstrumpet.html',
#  'charybdishellerii.html',
#  'chelidonurahirundinina.html',
#  'greenturtle.html',
#  'chicoreusbrevifrons.html',
#  'bridledburrfish.html',
#  'webburrfish.html',
#  'chilomycterusreticulatus.html',
#  'squamosechiton.html',
#  'chitonviridis.html',
#  'whitespottedfireworm.html',
#  'bluechromis.html',
#  'chromisenchrysura.html',
#  'sunshinefish.html',
#  'brownchromis.html',
#  'orangeballsponge.html',
#  'rednightshrimp.html',
#  'westindiantopsnail.html',
#  'orangeveinedencrusting.html',
#  'peachencrustingsponge.html',
#  'paintedtunicate.html',
#  'bluebelltunicate.html',
#  'creolewrasse.html',
#  'clibanariustricolor.html',
#  'coralencrustingsponge.html',
#  'redboring.html',
#  'clionatenuis.html',
#  'brownvariable.html',
#  'boulderbraincoral.html',
#  'giantanemone.html',
#  'conusdaucus.html',
#  'corallianassalongiventris.html',
#  'corollaspectabilis.html',
#  'orangeballcorallimorph.html',
#  'flabellinahamanni.html',
#  'colongoby.html',
#  'pallidgoby.html',
#  'bridledgoby.html',
#  'peppermintgoby.html',
#  'glassgoby.html',
#  'coryphopterustortugae.html',
#  'coryphopterusvenezuelae.html',
#  'neckcrab.html',
#  'shortfinpipefish.html',
#  'brownbowl.html',
#  'croniousruber.html',
#  'cryptosomabairdii.html',
#  'roughfileclam.html',
#  'cymbovulasp1.html',
#  'triangularcyphoma.html',
#  'flamingo.html',
#  'atlanticgraycowry.html',
#  'dactylopterusvolitans.html',
#  'dardanusfucosus.html',
#  'stareyehermitcrab.html',
#  'southernray.html',
#  'beadedcrinoid.html',
#  'goldencrinoid.html',
#  'frondoyster.html',
#  'pillarcoral.html',
#  'dercitusluteus.html',
#  'lumpyovergrowingsponge.html',
#  'urchin.html',
#  'ellipticalstarcoral.html',
#  'greenbubbleweed.html',
#  'ybranchedalgae.html',
#  'whitespecktunicate.html',
#  'colorfulsearod.html',
#  'balloon.html',
#  'porcupine.html',
#  'redorangeencrustingsponge.html',
#  'orangesieveencrustingsponge.html',
#  'diplectrumbivittatum.html',
#  'diplectrumformosum.html',
#  'spottailpinfish.html',
#  'knobbybraincoral.html',
#  'groovedbrain.html',
#  'forkedtentaclecorallimorph.html',
#  'dissodactylusprimitivus.html',
#  'buttontunicate.html',
#  'redeyespongecrab.html',
#  'sharksucker.html',
#  'echeneisneucratoides.html',
#  'chainmoray.html',
#  'rockurchin.html',
#  'reefurchin.html',
#  'mangrovetunicate.html',
#  'brownencrustingoctopus.html',
#  'caymancleaninggoby.html',
#  'orangesidedgoby.html',
#  'sharknosegoby.html',
#  'cleaninggoby.html',
#  'yellowlinegoby.html',
#  'barsnoutgoby.html',
#  'elacatinuslori.html',
#  'spotlightgoby.html',
#  'yellownosegoby.html',
#  'neongoby.html',
#  'rainbowrunner.html',
#  'devilsseawhip.html',
#  'longseawhip.html',
#  'bushyseawhip.html',
#  'lettuceseaslug.html',
#  'ornateelysia.html',
#  'sailfinblenny.html',
#  'flagfinblenny.html',
#  'chestnutmoray.html',
#  'mulattocongereel.html',
#  'blackedgetriplefin.html',
#  'eostichopusarnesoni.html',
#  'redhind.html',
#  'goliathgrouper.html',
#  'nassau.html',
#  'jackknife.html',
#  'spotteddrum.html',
#  'hawksbill.html',
#  'encrustinggorgonian.html',
#  'slatepencilurchin.html',
#  'blackcondominiumtunicate.html',
#  'whitecondominiumtunicate.html',
#  'strawberrytunicate.html',
#  'swollenknobcandelabrum.html',
#  'knobbysearods.html',
#  'redspotcombjelly.html',
#  'eurythoecomplanata.html',
#  'smoothflowercoral.html',
#  'truetulipshell.html',
#  'golfballcoral.html',
#  'fistulariatabacaria.html',
#  'flabellinaengeli.html',
#  'tubularthicketalgae.html',
#  'gastropteronchacmol.html',
#  'leatherybarrelspounge.html',
#  'yellowfinmojarra.html',
#  'nurseshark.html',
#  'pilotwhale.html',
#  'seagoddess.html',
#  'goldspotgoby.html',
#  'gnathophyllumamericanum.html',
#  'quillfin.html',
#  'venusseafan.html',
#  'meshfan.html',
#  'commonfan.html',
#  'fairybasslet.html',
#  'blackcapbasslet.html',
#  'featherhydroid.html',
#  'greenmoray.html',
#  'goldentailmoray.html',
#  'spottedmoray.html',
#  'purplemouthmoray.html',
#  'whitemargate.html',
#  'tomtate.html',
#  'caesargrunt.html',
#  'frenchgrunt.html',
#  'spanishgrunt.html',
#  'cottonwick.html',
#  'sailorchoice.html',
#  'whitegrunt.html',
#  'bluestripedgrunt.html',
#  'slipperydick.html',
#  'yellowcheekwrasse.html',
#  'yellowheadwrasse.html',
#  'clownwrasse.html',
#  'rainbowwrasse.html',
#  'blackearwrasse.html',
#  'puddingwife.html',
#  'largeleafvine.html',
#  'starencrustingsponge.html',
#  'sunraylettucecoral.html',
#  'ballyhoo.html',
#  'fireworm.html',
#  'browngardeneel.html',
#  'glasseye.html',
#  'caribbeanwhiptailstingray.html',
#  'hippocampuserectus.html',
#  'longsnoutseahorse.html',
#  'blueangel.html',
#  'queenangel.html',
#  'rockbeauty.html',
#  'squirrel.html',
#  'longspinesquirrel.html',
#  'floridaseacucumber.html',
#  'donkeycucumber.html',
#  'tigertailcucumber.html',
#  'hydatinaphysis.html',
#  'hydrozoanthustunicans.html',
#  'yellowbellyhamlet.html',
#  'yellowtailhamlet.html',
#  'bluehamlet.html',
#  'shyhamlet.html',
#  'indigohamlet.html',
#  'blackhamlet.html',
#  'barredhamlet.html',
#  'tanhamlet.html',
#  'hamlethyb.html',
#  'butterhamlet.html',
#  'hypselodorismarci.html',
#  'ruffledfeather.html',
#  'deepwaterfan.html',
#  'boga.html',
#  'greenfinger.html',
#  'irciniacampana.html',
#  'stinkersponge.html',
#  'blackball.html',
#  'iridopagurusreticulatus.html',
#  'iridopagurussp1.html',
#  'tubeanemone.html',
#  'flattreeoyster.html',
#  'roughstarcoral.html',
#  'threerowedcucumber.html',
#  'janiceaantiguensis.html',
#  'redbandedlobster.html',
#  'kyphosuscinerascens.html',
#  'chub.html',
#  'kyphosusvaigiensis.html',
#  'labrisomusconditus.html',
#  'labrisomuscricota.html',
#  'hairyblenny.html',
#  'hogfish.html',
#  'spottedtrunk.html',
#  'buffalotrunkfish.html',
#  'smoothtrunk.html',
#  'knobbyanemone.html',
#  'lebruniacoralligens.html',
#  'branchinganemone.html',
#  'whitecrypticsponge.html',
#  'wartycombjelly.html',
#  'antilleanfileclam.html',
#  'horseshoecrab.html',
#  'seathimblejellyfish.html',
#  'candybasslet.html',
#  'peppermintbasslet.html',
#  'starsnail.html',
#  'encrustingfanleaf.html',
#  'medusaworm.html',
#  'lolligunculabrevis.html',
#  'arrowblenny.html',
#  'luidiaalternata.html',
#  'muttonsnapper.html',
#  'schoolmaster.html',
#  'blackfinsnapper.html',
#  'cuberasnapper.html',
#  'graysnapper.html',
#  'dogsnapper.html',
#  'mahogany.html',
#  'lanesnapper.html',
#  'lygdamiswirtzi.html',
#  'lysiosquillinaglabriuscula.html',
#  'lysiosquillascabricauda.html',
#  'scarletshrimp.html',
#  'lysmatapederseni.html',
#  'variegatedurchin.html',
#  'lytechinuswilliamsi.html',
#  'macrocoelomatrispinosum.html',
#  'stingingbushhydroid.html',
#  'whitestinger.html',
#  'milkconch.html',
#  'macrotritopusdefilippi.html',
#  'tenraystarcoral.html',
#  'yellowpencil.html',
#  'sandtile.html',
#  'goldlineblenny.html',
#  'diamondblenny.html',
#  'saddledblenny.html',
#  'rosecoral.html',
#  'giantmanta.html',
#  'whitevalleymazecoral.html',
#  'mazecoral.html',
#  'shyfeatherduster.html',
#  'tarpon.html',
#  'melanellahypsela.html',
#  'blackdurgon.html',
#  'menippemercenaria.html',
#  'menippenodifrons.html',
#  'redhearturchin.html',
#  'carribeanvelvetshrimp.html',
#  'micrognathuscrinitus.html',
#  'yellowtaildamsel.html',
#  'bladefirecoral.html',
#  'branchingfire.html',
#  'redridgedclingingcrab.html',
#  'bandedclingingcrab.html',
#  'mithraxhispidus.html',
#  'channelcrab.html',
#  'fringedfilefish.html',
#  'slenderfile.html',
#  'redencrustingsponge.html',
#  'pinklumpysponge.html',
#  'greatstarcoral.html',
#  'yellowgoat.html',
#  'munidapusilla.html',
#  'spinyflowercoral.html',
#  'orangeicingsponge.html',
#  'strawberrysponge.html',
#  'knobbycactus.html',
#  'roughcactuscoral.html',
#  'ridgedcactus.html',
#  'blackgrouper.html',
#  'yellowmouthgrouper.html',
#  'tiger.html',
#  'yellowfingrouper.html',
#  'sharptaileel.html',
#  'goldspottedeel.html',
#  'blackbarsoldier.html',
#  'Mysidiumspp.html',
#  'aglajafelis.html',
#  'lesserray.html',
#  'lemonshark.html',
#  'bwcrinoid.html',
#  'touchmenot.html',
#  'darkmantis.html',
#  'longjawsquirrel.html',
#  'neslongus.html',
#  'pinkvase.html',
#  'lavenderropespounge.html',
#  'brownfanworm.html',
#  'yellowfanworm.html',
#  'roughtubesponge.html',
#  'reefoctopus.html',
#  'octopusmacropus.html',
#  'commonoctopus.html',
#  'diffuseivorybushcoral.html',
#  'yellowtailsnapper.html',
#  'ogcocephalusnasutus.html',
#  'olivareticularis.html',
#  'ophichthusophis.html',
#  'cometstar.html',
#  'redlipblenny.html',
#  'bluntspinedbrittlestar.html',
#  'spinybrittlestar.html',
#  'circlemarkedbrittlestar.html',
#  'ophiodermaphoenium.html',
#  'rubybrittlestar.html',
#  'reticulatedbrittlestar.html',
#  'ophiopsilariisei.html',
#  'ophiothrixoerstedii.html',
#  'spongebrittlestar.html',
#  'jawfish.html',
#  'bandedjawfish.html',
#  'duskyjawfish.html',
#  'lobedstarcoral.html',
#  'mountainousstarcoral.html',
#  'boulderstarcoral.html',
#  'seastar.html',
#  'leafyrolledblade.html',
#  'whitescrollalga.html',
#  'redreefhermit.html',
#  'paguristeserythrops.html',
#  'speckeledhermit.html',
#  'blueeyehermitcrab.html',
#  'shortfingerhermit.html',
#  'whiteencrustingzoanthid.html',
#  'pandarosacanthifolium.html',
#  'lobster.html',
#  'spottedlobster.html',
#  'parablenniusmarmoreus.html',
#  'creolefish.html',
#  'goldenzoanthid.html',
#  'highhat.html',
#  'parequesumbrosus.html',
#  'sculpturedslipperlobster.html',
#  'peliamutica.html',
#  'peliarotunda.html',
#  'glassysweeper.html',
#  'penicilluspyriformis.html',
#  'christmastreehydroid.html',
#  'nimblespraycrab.html',
#  'periclimenescfmeyeri.html',
#  'periclimenesiridescens.html',
#  'sunanemoneshrimp.html',
#  'spottedcleanershrimp.html',
#  'gianthermit.html',
#  'petrolisthesamoenus.html',
#  'burgundycrustalgae.html',
#  'polkadottedhermitcrab.html',
#  'phimochirusrandalli.html',
#  'phoronisaustralis.html',
#  'phylliroebucephalum.html',
#  'beadedanemone.html',
#  'pickfordiateuthispulchella.html',
#  'amberpenshell.html',
#  'tidalspraycrab.html',
#  'viscoussponge.html',
#  'plakortishalichondrioides.html',
#  'platypodiellaspectabilis.html',
#  'bentsearod.html',
#  'blacksearod.html',
#  'slitporesearod.html',
#  'gianttunicate.html',
#  'polycerasp1.html',
#  'grayangel.html',
#  'frenchangel.html',
#  'horseshoeworm.html',
#  'mustardhill.html',
#  'thinfingercoral.html',
#  'branchedfingercoral.html',
#  'fingercoral.html',
#  'sargassumswimmingcrab.html',
#  'priacanthusarenatus.html',
#  'rustygoby.html',
#  'longsnoutbutter.html',
#  'pseudoceroscrozieri.html',
#  'redspottedhorseshoeworm.html',
#  'poroussearods.html',
#  'leopardflatworm.html',
#  'symmetricalbrain.html',
#  'pseudopontonidesprincipis.html',
#  'pseudosquillaciliata.html',
#  'hiddenseacucumber.html',
#  'spottedgoat.html',
#  'wingoyster.html',
#  'angularseawhip.html',
#  'groovedbladeseawhip.html',
#  'commonlionfish.html',
#  'ptilocauliswalpersi.html',
#  'pyrosomaatlanticum.html',
#  'whitefanbryozoan.html',
#  'whaleshark.html',
#  'pinecone.html',
#  'rhizosmiliamaculata.html',
#  'wartycorallimorph.html',
#  'reeftunicate.html',
#  'floridacorallimorph.html',
#  'tuskedgoby.html',
#  'freckledsoapfish.html',
#  'greatersoapfish.html',
#  'rypticussubbifrenatus.html',
#  'magnificentfeatherduster.html',
#  'seafrost.html',
#  'salpamaxima.html',
#  'pelagictunicate.html',
#  'sanopusastrifer.html',
#  'splendidtoad.html',
#  'sargassumseaweed.html',
#  'whiteveinsargassum.html',
#  'reefsquirrel.html',
#  'duskysquirrel.html',
#  'midnightparrot.html',
#  'blueparrot.html',
#  'rainbowparrot.html',
#  'stripedparrotfish.html',
#  'princessparrot.html',
#  'queenparrot.html',
#  'diskcoral.html',
#  'atlanticmushroomcoral.html',
#  'cero.html',
#  'orangelumpyencrustingsponge.html',
#  'scorpaenaalbifimbria.html',
#  'scorpaenagrandicornis.html',
#  'mushroomscorpionfish.html',
#  'scorpion.html',
#  'reefscorpionfish.html',
#  'spanishlobster.html',
#  'reefsquid.html',
#  'almacojack.html',
#  'lanternbass.html',
#  'serranussubligarius.html',
#  'tobacco.html',
#  'harlequinbass.html',
#  'chalkbass.html',
#  'branchinghydroid.html',
#  'lesserstarletcoral.html',
#  'massivestarlet.html',
#  'variableboring.html',
#  'smenospongiaconulosa.html',
#  'smoothstarcoral.html',
#  'greenblotchparrotfish.html',
#  'redbandparrot.html',
#  'redtailparrot.html',
#  'yellowtailparrot.html',
#  'stoplightparrotfish.html',
#  'loggerheadsponge.html',
#  'bandtailpuffer.html',
#  'checkeredpuffer.html',
#  'barracuda.html',
#  'pinkredencrusting.html',
#  'spirastrellahartmani.html',
#  'spirobranchusgiganteus.html',
#  'thornyoyster.html',
#  'duskydamsel.html',
#  'longfindamselfish.html',
#  'beaugregory.html',
#  'bicolordamsel.html',
#  'threespotdamsel.html',
#  'cocoadamselfish.html',
#  'spinnerdolphin.html',
#  'slenderchiton.html',
#  'coralshrimp.html',
#  'goldencoralshrimp.html',
#  'arrowcrab.html',
#  'blushingstarcoral.html',
#  'sunanemone.html',
#  'wirecoral.html',
#  'strombusalatus.html',
#  'redfinneedlefish.html',
#  'roselace.html',
#  'volcanosponge.html',
#  'channelflounder.html',
#  'symphurusdiomedeanus.html',
#  'encrustingsocialtunicates.html',
#  'sanddiver.html',
#  'bluestripedlizardfish.html',
#  'clubtippedanemone.html',
#  'bluehead.html',
#  'caribbeansquatshrimp.html',
#  'thuridillapicta.html',
#  'algaehydroid.html',
#  'tigrigobiusharveyi.html',
#  'greenbandedgoby.html',
#  'topsentiaophiraphidites.html',
#  'permit.html',
#  'palometa.html',
#  'trachycarisrugosa.html',
#  'bleedingteethbryozoan.html',
#  'westindianmanatee.html',
#  'overgrowingmattunicate.html',
#  'westindianseaegg.html',
#  'tritoniabayeri.html',
#  'orangecupcoral.html',
#  'turbinellaangulata.html',
#  'dolphin.html',
#  'mermaidsfan.html',
#  'mottledmojarra.html',
#  'spongezoanthid.html',
#  'yellowray.html',
#  'seapearls.html',
#  'nettedbarrel.html',
#  'verongulareiswigi.html',
#  'pittedsponge.html',
#  'pinkbushalga.html',
#  'sargassumtrigger.html',
#  'giantbarrel.html',
#  'xestospongiarosariensis.html',
#  'rosyrazorfish.html',
#  'pearlyrazorfish.html',
#  'greenrazor.html',
#  'matzoanthid.html']

# %%
len(ref_lst)
# Out:
# 685

# %% [markdown]
# Hmmmm so that was effective however I have realized that this list contains coral, sponges, invertebrates as well. let's look at a species page and see if there is anything we can use to ID fish entries.

# %%
needle_URL = 'https://reefguide.org/carib/flatneedle.html'
needle_page = requests.get(needle_URL)
needle_soup = BeautifulSoup(needle_page.content, "html.parser") # lol

# %%
print(needle_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Flat Needlefish - Ablennes hians - Needlefishes -  - Caribbean Reefs
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Florent's Guide To The Caribbean Reefs - Flat Needlefish - Ablennes hians - Needlefishes -  - Needlefishes - Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia - " name="description"/>
#   <meta content="Florent's Guide To The Caribbean Reefs - Flat Needlefish - Ablennes hians - Needlefishes -  - Needlefishes - Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia - " name="keywords"/>
#   <meta content="Florent Charpin" name="author"/>
#   <script src="jquery/js/jquery-1.7.1.min.js" type="text/javascript">
#   </script>
#   <script src="jquery/js/jquery-ui-1.8.16.custom.min.js" type="text/javascript">
#   </script>
#   <script src="js/mainindex.js" type="text/javascript">
#   </script>
#   <link href="jquery/css/ui-lightness/jquery-ui-1.8.16.custom.css" rel="Stylesheet" type="text/css"/>
#   <link href="css/all.css" rel="stylesheet" type="text/css"/>
#   <link href="css/species.css" rel="stylesheet" type="text/css"/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3281928-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-3281928-1');
#   </script>
#  </head>
#  <!--
#          Web site design and all photographs copyright 2004-2023 Florent Charpin. All rights reserved. Email: www@reefguide.org
#     -->
#  <body>
#   <script>
#    $(document).ready(SpeciesInit);
#   </script>
#   <div id="maincontainer">
#    <div class="banner3" id="topsection">
#     <h4>
#      Florent's Guide To The
#      <span class="pretitle">
#       Florida, Bahamas &amp;
#      </span>
#     </h4>
#     <h1>
#      Caribbean Reefs
#     </h1>
#     <ul class="topnav">
#      <li class="ba">
#       <a href="../home.html">
#        Home
#       </a>
#      </li>
#      <li>
#       <span class="ba">
#        <a>
#         Area
#        </a>
#       </span>
#       <ul class="subnav">
#        <li>
#         <a href="../carib/index1.html">
#          <div class="ui-icon ui-icon-check arrow">
#          </div>
#          Caribbean
#         </a>
#        </li>
#        <li>
#         <a href="../indopac/index1.html">
#          <div class="arrow2">
#          </div>
#          Pacific
#         </a>
#        </li>
#        <li>
#         <a href="../keys/index1.html">
#          <div class="arrow2">
#          </div>
#          South Florida
#         </a>
#        </li>
#        <li>
#         <a href="../hawaii/index1.html">
#          <div class="arrow2">
#          </div>
#          Hawaii
#         </a>
#        </li>
#        <li>
#         <a href="../baja/index1.html">
#          <div class="arrow2">
#          </div>
#          Eastern Pacific
#         </a>
#        </li>
#        <li>
#         <a href="../fp/index1.html">
#          <div class="arrow2">
#          </div>
#          French Polynesia
#         </a>
#        </li>
#        <li>
#         <a href="../index1.html">
#          <div class="arrow2">
#          </div>
#          Worldwide
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <span class="ba">
#        <a>
#         Index
#        </a>
#       </span>
#       <ul class="subnav">
#        <li>
#         <a href="cat.html">
#          By Common Names
#         </a>
#        </li>
#        <li>
#         <a href="cat_grp.html">
#          By Categories
#         </a>
#        </li>
#        <li>
#         <a href="cat_sci.html">
#          By Scientific Names
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="ba">
#       <a href="../latest.html">
#        Updates
#       </a>
#      </li>
#      <li class="ba">
#       <a href="../about.html">
#        About
#       </a>
#      </li>
#      <li class="ba">
#       <a href="http://reefguide.org/reefguide.xml">
#        RSS
#       </a>
#      </li>
#      <li class="ba">
#       <a href="../search.html?area=1">
#        Search Species
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div id="contentwrapper">
#     <div id="contentcolumn">
#      <div class="typetitle">
#       Flat Needlefish
#      </div>
#      <div id="content">
#       <div>
#        <div id="gallery">
#         <div class="galleryspan">
#          <a class="pixsel" href="pixhtml/flatneedle1.html">
#           <img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/>
#          </a>
#          <div class="main2">
#           St Kitts
#          </div>
#          <div class="main3">
#          </div>
#         </div>
#         <div class="galleryspan">
#          <a class="pixsel" href="pixhtml/flatneedle2.html">
#           <img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle2.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/>
#          </a>
#          <div class="main2">
#           St Kitts
#          </div>
#          <div class="main3">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="leftcolumn" style="font-size: 10px;">
#     <div class="innertube">
#      <div class="ui-state-default ui-corner-all infobox">
#       <div class="navbox" style="margin-left: 0px; margin-top: 5px;  margin-bottom: 5px; text-align: left;">
#        <div class="ui-icon ui-icon-arrowreturnthick-1-w navbox" style="float:left; vertical-align: middle">
#        </div>
#        <div style="margin: 0px;">
#         <a href="index3.html#Needlefishes">
#          Back to
#          <i>
#           Needlefishes
#          </i>
#          page
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="ui-state-default ui-corner-all infobox">
#       <div class="titledetails">
#        Flat Needlefish
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Scientific Name:
#        </span>
#        <span class="sntitle">
#         Ablennes hians
#        </span>
#       </div>
#       <div class="infodetails">
#       </div>
#       <div class="infodetails">
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Family:
#        </span>
#        <span class="sntitle">
#         Belonidae
#        </span>
#       </div>
#       <div class="infodetails">
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Category:
#        </span>
#        <span class="details2">
#         Needlefishes
#        </span>
#       </div>
#       <div class="infodetails">
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Size:
#        </span>
#        <span class="details2">
#         1 to 3 feet (30 to 90 cm)
#        </span>
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Depth:
#        </span>
#        <span class="details2">
#         0-30 ft. (0-10 m)
#        </span>
#       </div>
#       <div class="infodetails">
#        <span class="details">
#         Distribution:
#        </span>
#        <span class="details2">
#         Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia
#        </span>
#       </div>
#       <br/>
#      </div>
#      <div class="ui-state-default ui-corner-all infobox">
#       <div class="navbox" style="margin-left: 5px;">
#        <span class="ui-icon ui-icon-triangle-1-e" style="display: inline-block; vertical-align: middle">
#        </span>
#        <span style="margin-left: 0px;">
#         <a href="index3.html">
#          Silvery fishes
#         </a>
#        </span>
#       </div>
#       <div class="navbox" style="margin-left: 10px;__HIDDEN2__">
#        <span class="ui-icon ui-icon-triangle-1-s" style="display: inline-block; vertical-align: middle">
#        </span>
#        <span style="margin-left: 0px;">
#         Needlefishes
#        </span>
#       </div>
#       <br/>
#       <div class="infoimg">
#        <a href="flatneedle.html">
#         <img alt="" src="../pix/thumb3/flatneedle1.jpg" title=""/>
#         <div>
#          Flat Needlefish
#         </div>
#        </a>
#       </div>
#       <br/>
#       <div class="infoimg">
#        <a href="redfinneedlefish.html">
#         <img alt="" src="../pix/thumb3/redfinneedlefish1.jpg" title=""/>
#         <div>
#          Redfin Needlefish
#         </div>
#        </a>
#       </div>
#       <br/>
#       <br/>
#      </div>
#      <br/>
#      All Photographs
#      <br/>
#      © 2023 Florent Charpin
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(' '.join(needle_soup.get_text().split()))
# Out:
# Flat Needlefish - Ablennes hians - Needlefishes - - Caribbean Reefs Florent's Guide To The Florida, Bahamas & Caribbean Reefs Home Area Caribbean Pacific South Florida Hawaii Eastern Pacific French Polynesia Worldwide Index By Common Names By Categories By Scientific Names Updates About RSS Search Species Flat Needlefish St Kitts St Kitts Back to Needlefishes page Flat Needlefish Scientific Name: Ablennes hians Family: Belonidae Category: Needlefishes Size: 1 to 3 feet (30 to 90 cm) Depth: 0-30 ft. (0-10 m) Distribution: Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia Silvery fishes Needlefishes Flat NeedlefishRedfin Needlefish All Photographs© 2023 Florent Charpin

# %%
needle_soup.find_all('div',{'class':'infodetails'})
# Out:
# [<div class="infodetails"><span class="details">Scientific Name: </span><span class="sntitle">Ablennes hians</span></div>,
#  <div class="infodetails"> </div>,
#  <div class="infodetails"></div>,
#  <div class="infodetails"><span class="details">Family: </span><span class="sntitle">Belonidae</span></div>,
#  <div class="infodetails"></div>,
#  <div class="infodetails"><span class="details">Category: </span><span class="details2">Needlefishes</span></div>,
#  <div class="infodetails"></div>,
#  <div class="infodetails"><span class="details">Size: </span><span class="details2">1 to 3 feet (30 to 90 cm)</span>  </div>,
#  <div class="infodetails"><span class="details">Depth: </span><span class="details2">0-30 ft. (0-10 m)</span></div>,
#  <div class="infodetails"><span class="details">Distribution: </span><span class="details2">Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia</span></div>]

# %%
[result.get_text() for result in needle_soup.find_all('div',{'class':'infodetails'})]
# Out:
# ['Scientific Name: Ablennes hians',
#  ' ',
#  '',
#  'Family: Belonidae',
#  '',
#  'Category: Needlefishes',
#  '',
#  'Size: 1 to 3 feet (30 to 90 cm)\xa0\xa0',
#  'Depth: 0-30 ft. (0-10 m)',
#  'Distribution: Florida, Caribbean, Bermuda, Bahamas, Brazil, Gulf of Mexico, Indo-Pacific, Australia']

# %%
details = [result.get_text() for result in needle_soup.find_all('div',{'class':'infodetails'})]
print(f"Scientific Name: {details[0].rsplit(': ')[-1]}")
print(f"Family Name: {details[3].rsplit(': ')[-1]}")
print(f"Category Name: {details[5].rsplit(': ')[-1]}")
range_idx_start = details[7].find('(') + 1
range_idx_end = details[7].find(')') - 3
print(f"range Range: {details[7][range_idx_start:range_idx_end].split()[0:3:2]}")
depth_idx_start = details[8].find('(') + 1
depth_idx_end = details[8].find(')') - 2
print(f"Depth Range: {details[8][depth_idx_start:depth_idx_end].split('-')}")
print(f"Distribution: {details[9].rsplit(': ')[-1].split(', ')}")
# Out:
# Scientific Name: Ablennes hians
# Family Name: Belonidae
# Category Name: Needlefishes
# Size Range: ['30', '90']
# Depth Range: ['0', '10']
# Distribution: ['Florida', 'Caribbean', 'Bermuda', 'Bahamas', 'Brazil', 'Gulf of Mexico', 'Indo-Pacific', 'Australia']

# %%
[details[7].find('('),details[7].find(')')]
# Out:
# [18, 30]

# %%
needle_soup.find_all('a',{'class':'pixsel'})
# Out:
# [<a class="pixsel" href="pixhtml/flatneedle1.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>,
#  <a class="pixsel" href="pixhtml/flatneedle2.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle2.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>]

# %%
[result for result in needle_soup.find_all('a',{'class':'pixsel'})]
# Out:
# [<a class="pixsel" href="pixhtml/flatneedle1.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>,
#  <a class="pixsel" href="pixhtml/flatneedle2.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle2.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>]

# %%
needle_soup.find_all('img')
# Out:
# [<img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/>,
#  <img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle2.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/>,
#  <img alt="" src="../pix/thumb3/flatneedle1.jpg" title=""/>,
#  <img alt="" src="../pix/thumb3/redfinneedlefish1.jpg" title=""/>]

# %%
[result.get('src') for result in needle_soup.find_all('img',{'class':'selframe'})]
# Out:
# ['../pix/thumb2/flatneedle1.jpg', '../pix/thumb2/flatneedle2.jpg']

# %%
img_link = 'https://reefguide.org/pix/flatneedle1.jpg'
img_data = requests.get(img_link).content
with open('needlefish_test.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
[result.get_text() for result in needle_soup.find_all('div',{'class':'main3'})]
# Out:
# ['\xa0', '\xa0']

# %%
needle_soup.find_all('div',{'class':'galleryspan'})
# Out:
# [<div class="galleryspan">
#  <a class="pixsel" href="pixhtml/flatneedle1.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>
#  <div class="main2">St Kitts</div>
#  <div class="main3"> </div>
#  </div>,
#  <div class="galleryspan">
#  <a class="pixsel" href="pixhtml/flatneedle2.html"><img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle2.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/></a>
#  <div class="main2">St Kitts</div>
#  <div class="main3"> </div>
#  </div>]

# %%
image_groups = needle_soup.find_all('div',{'class':'galleryspan'})
first_image = image_groups[0]
print(first_image.find('img'))
print(first_image.find('main3'))
print(first_image.find('img').get('src').rsplit('/',1)[-1])
# Out:
# <img alt="Flat Needlefish - Ablennes hians - St Kitts" class="selframe" src="../pix/thumb2/flatneedle1.jpg" title="Flat Needlefish - Ablennes hians - St Kitts"/>
# None
# flatneedle1.jpg

# %%
first_image.find('main3') == None
# Out:
# True

# %%
needle_soup.find_all('div',{'class':'typetitle'})[0].get_text()
# Out:
# 'Flat Needlefish'

# %% [markdown]
# Okay.. so I think from this we have figured out how to get all the information we are currently interested in, plus a way to download and save the images. Lets put together a function that will do everything, taking in only the reference we got from the list of species above and a flag for whether or not we should download the images.

# %%
def reefguide_scrape(species_suffix,download_flag):
    ### This function takes in the end of a URL and uses it to access the appropriate webpage on reefguide.org
    ### For example, being passed 'flatneedle.html' will access the URL 'https://reefguide.org/carib/flatneedle.html'
    ### It will then collect the desired species information from the web page as well as download all the images
    ### If the download flag is boolean True using the function reefguide_images and store them in the appropriate folder
    ### on my HDD.

    # Get page HTML

    reefguide_prefix = 'https://reefguide.org/carib/'
    species_URL = reefguide_prefix + species_suffix
    species_page = requests.get(species_URL)
    species_soup = BeautifulSoup(species_page.content, "html.parser")
    
    # Get Common Name

    common_name = species_soup.find_all('div',{'class':'typetitle'})[0].get_text()

    # Get info from details box

    details = [result.get_text() for result in species_soup.find_all('div',{'class':'infodetails'})]

    # Extract Scientific Name, Scientific Family, and Common Family Name

    scientific_name = details[0].rsplit(': ')[-1]
    scientific_family = details[3].rsplit(': ')[-1]
    common_family = details[5].rsplit(': ')[-1]

    # Extract Size and Depth Ranges
    # There is a helper function defined below

    size_range_cm = range_handler(details[7].rsplit(': ')[-1])

    # couple cases where depth doesn't exist

    try:
        depth_range_cm = range_handler(details[8].rsplit(': ')[-1])
        depth_range_m = (depth_range_cm[0] / 100, depth_range_cm[1] / 100) 
    except:
        depth_range_m = (0,0)
        
    # Extract Distribution str list

    geodist = details[9].rsplit(': ')[-1].split(', ')

    if download_flag:
        reefguide_download(species_soup, scientific_family, scientific_name)
    else:
        pass

    return [ scientific_name, scientific_family, common_name, common_family, size_range_cm, depth_range_m, geodist ]

def reefguide_download(species_soup,scientific_family,scientific_name):
    ### This function downloads all images from the species page and stores them in a species labelled folder on my HDD
    ### The folder is named for the scientific name as well as fits into the scientific family heirarchy
    ### The function will separate images into different folders based on labels such as juvenile, initial

    reefguide_pix_prefix = 'https://reefguide.org/pix/'

    image_groups = species_soup.find_all('div',{'class':'galleryspan'})
    for image in image_groups:

        # Get Image URL and image data

        image_suffix = image.find('img').get('src').rsplit('/',1)[-1]
        img_link = reefguide_pix_prefix + image_suffix
        img_data = requests.get(img_link).content

        # Determine if image has phase label such as juvenile, initial, terminal. If not, leave blank
        try:
            phase_tag = image.find_all('div', {'class': 'main3'})[0].get_text()
        except:
            phase_tag = None

        if phase_tag == None:
            phase_tag = ''
        else:
            phase_tag = phase_tag.replace(' ','_')

        # Construct save path

        path_prefix = 'E:/LargeDatasets/SpeciesID-Images/'
        folder_path = path_prefix + scientific_family + '/' + scientific_name.replace(' ','_') + '_' + phase_tag
        img_path = folder_path + '/' + image_suffix

        # check if path exists and if not make it so

        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # check if file already exists and if so skip

        if os.path.exists(img_path):
            continue
        
        with open(img_path, 'wb') as handler:
            handler.write(img_data)

    return

# %%
reefguide_scrape('rainbowparrot.html',1)
# Out:
# ['Scarus guacamaia',
#  'Scaridae',
#  'Rainbow Parrotfish',
#  'Parrotfishes',
#  (45.0, 150.0),
#  (3.0, 25.0),
#  ['Caribbean', 'Bahamas', 'Florida', 'Bermuda']]

# %%
columns = [ 'scientific_name', 'scientific_family', 'common_name', 'common_family', 'range_cm', 'depth_range_m', 'geodist' ]
FishDF = pd.DataFrame(columns = columns)
FishDF
# Out:
# Empty DataFrame
# Columns: [scientific_name, scientific_family, common_name, common_family, size_range_cm, depth_range_m, geodist]
# Index: []

# %%
FishDF.loc[len(FishDF)] = reefguide_scrape('flatneedle.html',0)
FishDF
# Out:
#           scientific_name   scientific_family      common_name common_family  \
# 0          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
# 1  Ginglymostoma cirratum  Ginglymostomatidae      Nurse Shark  Nurse Sharks
# 2          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
# 3  Ginglymostoma cirratum  Ginglymostomatidae      Nurse Shark  Nurse Sharks
# 4          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
#
#     size_range_cm depth_range_m  \
# 0    (30.0, 90.0)   (0.0, 10.0)
# 1  (150.0, 350.0)   (4.0, 30.0)
# 2    (30.0, 90.0)   (0.0, 10.0)
# 3  (150.0, 350.0)   (4.0, 30.0)
# 4    (30.0, 90.0)   (0.0, 10.0)
#
#                                              geodist
# 0  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...
# 1  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 2  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...
# 3  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 4  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...

# %%
FishDF.loc[len(FishDF)] = reefguide_scrape('nurseshark.html',0)
FishDF
# Out:
#           scientific_name   scientific_family      common_name common_family  \
# 0          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
# 1  Ginglymostoma cirratum  Ginglymostomatidae      Nurse Shark  Nurse Sharks
# 2          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
# 3  Ginglymostoma cirratum  Ginglymostomatidae      Nurse Shark  Nurse Sharks
# 4          Ablennes hians           Belonidae  Flat Needlefish  Needlefishes
# 5  Ginglymostoma cirratum  Ginglymostomatidae      Nurse Shark  Nurse Sharks
#
#     size_range_cm depth_range_m  \
# 0    (30.0, 90.0)   (0.0, 10.0)
# 1  (150.0, 350.0)   (4.0, 30.0)
# 2    (30.0, 90.0)   (0.0, 10.0)
# 3  (150.0, 350.0)   (4.0, 30.0)
# 4    (30.0, 90.0)   (0.0, 10.0)
# 5  (150.0, 350.0)   (4.0, 30.0)
#
#                                              geodist
# 0  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...
# 1  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 2  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...
# 3  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 4  [Florida, Caribbean, Bermuda, Bahamas, Brazil,...
# 5  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...

# %% [markdown]
# Yoohooo!!!!! It works, and downloading the images works too. So.. now I have to decide if we want to use all the refs from the html list above, or if I want to manually go through and clean the list for only fish. I think that is what I will do so, lets bring back the list.

# %%
ref_lst
# Out:
# ['flatneedle.html',
#  'sergeantmajor.html',
#  'nightsergeant.html',
#  'roughheadblenny.html',
#  'secretaryblenny.html',
#  'spinyheadblenny.html',
#  'chiton.html',
#  'honeycomb.html',
#  'scrawledcowfish.html',
#  'surgeonfish.html',
#  'doctorfish.html',
#  'bluetang.html',
#  'greenmermaidswineglass.html',
#  'whitemermaidswineglass.html',
#  'redhairswimmingcrab.html',
#  'ocellateswimmingcrab.html',
#  'blotchedswimmingcrab.html',
#  'staghorn.html',
#  'elkhorncoral.html',
#  'elegantanemone.html',
#  'acyrtusartius.html',
#  'eagleray.html',
#  'scaledlettucecoral.html',
#  'lettucecoral.html',
#  'purplelettucecoral.html',
#  'fragilesaucercoral.html',
#  'dimpledsheetcoral.html',
#  'lowreliefletttuce.html',
#  'whitestarsheet.html',
#  'thinleaflettuce.html',
#  'agelascerebrum.html',
#  'agelascitrina.html',
#  'elephantear.html',
#  'agelasconifera.html',
#  'agelastubulata.html',
#  'brownclusteredtube.html',
#  'branchingtube.html',
#  'bonefish.html',
#  'aligergallus.html',
#  'queenconch.html',
#  'redsnappingshrimp.html',
#  'alpheuspolystictus.html',
#  'scrawledfile.html',
#  'hawkfish.html',
#  'pipehorse.html',
#  'erectropesponge.html',
#  'swimmingcrinoid.html',
#  'featherduster.html',
#  'ghostfeatherduster.html',
#  'pederson.html',
#  'isopod.html',
#  'anisonotuscurvirostris.html',
#  'blackmargate.html',
#  'porkfish.html',
#  'antennariusscaber.html',
#  'slimyseaplume.html',
#  'bipinnateseaplumes.html',
#  'seaplumes.html',
#  'grayseafanblackcoral.html',
#  'antipatheslenta.html',
#  'bushyblackcoral.html',
#  'featherblackcoral.html',
#  'spottedseahare.html',
#  'stovepipe.html',
#  'rowporeropesponge.html',
#  'yellowtube.html',
#  'scatteredporeropesponge.html',
#  'aplysinainsularis.html',
#  'convolutedbarrel.html',
#  'apogonbinotatus.html',
#  'whitestarcardinalfish.html',
#  'flamefish.html',
#  'palecardinalfish.html',
#  'apogonpseudomaculatus.html',
#  'apogonrobinsi.html',
#  'beltedcardinalfish.html',
#  'sheepshead.html',
#  'arctidesguineensis.html',
#  'clathrinacanariensis.html',
#  'greentubetunicate.html',
#  'furrycucumber.html',
#  'blackfincardinalfish.html',
#  'twospinedseastar.html',
#  'giantbasketstar.html',
#  'trumpet.html',
#  'moonjelly.html',
#  'axiopsisserratifrons.html',
#  'queentrigger.html',
#  'corkscrewanemone.html',
#  'largeeyetoadfish.html',
#  'brownspongezoanthid.html',
#  'maroonspongezoanthid.html',
#  'socialfeatherduster.html',
#  'variegatedfeatherduster.html',
#  'spotfinhogfish.html',
#  'spanishhogfish.html',
#  'peacock.html',
#  'eyedflounder.html',
#  'twoclawshrimp.html',
#  'smallmouthgrunt.html',
#  'blackspottedfeather.html',
#  'corkyseafinger.html',
#  'tutlegrassanemone.html',
#  'wartyseaanemone.html',
#  'redwartyseaanemone.html',
#  'joltheadporgy.html',
#  'saucereyeporgy.html',
#  'plumaporgy.html',
#  'calappaflammea.html',
#  'calappasulcata.html',
#  'calappulatortugae.html',
#  'orangeclawhermit.html',
#  'calliactistricolor.html',
#  'ornatebluecrab.html',
#  'bluecrab.html',
#  'lancerdragonet.html',
#  'callyspongiafallax.html',
#  'azurevase.html',
#  'branchingvase.html',
#  'whitespottedfile.html',
#  'orangespottedfile.html',
#  'oceantrigger.html',
#  'sharpnosepuffer.html',
#  'yellowjack.html',
#  'barjack.html',
#  'bluerunner.html',
#  'horseeyejack.html',
#  'blackjack.html',
#  'bullshark.html',
#  'reefshark.html',
#  'loggerheadturtle.html',
#  'whitetelesto.html',
#  'batwingcoralcrab.html',
#  'upsidedownjelly.html',
#  'mangroveupsidedownjelly.html',
#  'kinghelmet.html',
#  'caulerparacemosa.html',
#  'sawbladealga.html',
#  'cherubfish.html',
#  'graysby.html',
#  'coney.html',
#  'cestumveneris.html',
#  'chaenopsislimbaughi.html',
#  'spadefish.html',
#  'foureyebutterflyfish.html',
#  'spotfinbutter.html',
#  'reefbutterflyfish.html',
#  'bandedbutterfly.html',
#  'atlantictritonstrumpet.html',
#  'charybdishellerii.html',
#  'chelidonurahirundinina.html',
#  'greenturtle.html',
#  'chicoreusbrevifrons.html',
#  'bridledburrfish.html',
#  'webburrfish.html',
#  'chilomycterusreticulatus.html',
#  'squamosechiton.html',
#  'chitonviridis.html',
#  'whitespottedfireworm.html',
#  'bluechromis.html',
#  'chromisenchrysura.html',
#  'sunshinefish.html',
#  'brownchromis.html',
#  'orangeballsponge.html',
#  'rednightshrimp.html',
#  'westindiantopsnail.html',
#  'orangeveinedencrusting.html',
#  'peachencrustingsponge.html',
#  'paintedtunicate.html',
#  'bluebelltunicate.html',
#  'creolewrasse.html',
#  'clibanariustricolor.html',
#  'coralencrustingsponge.html',
#  'redboring.html',
#  'clionatenuis.html',
#  'brownvariable.html',
#  'boulderbraincoral.html',
#  'giantanemone.html',
#  'conusdaucus.html',
#  'corallianassalongiventris.html',
#  'corollaspectabilis.html',
#  'orangeballcorallimorph.html',
#  'flabellinahamanni.html',
#  'colongoby.html',
#  'pallidgoby.html',
#  'bridledgoby.html',
#  'peppermintgoby.html',
#  'glassgoby.html',
#  'coryphopterustortugae.html',
#  'coryphopterusvenezuelae.html',
#  'neckcrab.html',
#  'shortfinpipefish.html',
#  'brownbowl.html',
#  'croniousruber.html',
#  'cryptosomabairdii.html',
#  'roughfileclam.html',
#  'cymbovulasp1.html',
#  'triangularcyphoma.html',
#  'flamingo.html',
#  'atlanticgraycowry.html',
#  'dactylopterusvolitans.html',
#  'dardanusfucosus.html',
#  'stareyehermitcrab.html',
#  'southernray.html',
#  'beadedcrinoid.html',
#  'goldencrinoid.html',
#  'frondoyster.html',
#  'pillarcoral.html',
#  'dercitusluteus.html',
#  'lumpyovergrowingsponge.html',
#  'urchin.html',
#  'ellipticalstarcoral.html',
#  'greenbubbleweed.html',
#  'ybranchedalgae.html',
#  'whitespecktunicate.html',
#  'colorfulsearod.html',
#  'balloon.html',
#  'porcupine.html',
#  'redorangeencrustingsponge.html',
#  'orangesieveencrustingsponge.html',
#  'diplectrumbivittatum.html',
#  'diplectrumformosum.html',
#  'spottailpinfish.html',
#  'knobbybraincoral.html',
#  'groovedbrain.html',
#  'forkedtentaclecorallimorph.html',
#  'dissodactylusprimitivus.html',
#  'buttontunicate.html',
#  'redeyespongecrab.html',
#  'sharksucker.html',
#  'echeneisneucratoides.html',
#  'chainmoray.html',
#  'rockurchin.html',
#  'reefurchin.html',
#  'mangrovetunicate.html',
#  'brownencrustingoctopus.html',
#  'caymancleaninggoby.html',
#  'orangesidedgoby.html',
#  'sharknosegoby.html',
#  'cleaninggoby.html',
#  'yellowlinegoby.html',
#  'barsnoutgoby.html',
#  'elacatinuslori.html',
#  'spotlightgoby.html',
#  'yellownosegoby.html',
#  'neongoby.html',
#  'rainbowrunner.html',
#  'devilsseawhip.html',
#  'longseawhip.html',
#  'bushyseawhip.html',
#  'lettuceseaslug.html',
#  'ornateelysia.html',
#  'sailfinblenny.html',
#  'flagfinblenny.html',
#  'chestnutmoray.html',
#  'mulattocongereel.html',
#  'blackedgetriplefin.html',
#  'eostichopusarnesoni.html',
#  'redhind.html',
#  'goliathgrouper.html',
#  'nassau.html',
#  'jackknife.html',
#  'spotteddrum.html',
#  'hawksbill.html',
#  'encrustinggorgonian.html',
#  'slatepencilurchin.html',
#  'blackcondominiumtunicate.html',
#  'whitecondominiumtunicate.html',
#  'strawberrytunicate.html',
#  'swollenknobcandelabrum.html',
#  'knobbysearods.html',
#  'redspotcombjelly.html',
#  'eurythoecomplanata.html',
#  'smoothflowercoral.html',
#  'truetulipshell.html',
#  'golfballcoral.html',
#  'fistulariatabacaria.html',
#  'flabellinaengeli.html',
#  'tubularthicketalgae.html',
#  'gastropteronchacmol.html',
#  'leatherybarrelspounge.html',
#  'yellowfinmojarra.html',
#  'nurseshark.html',
#  'pilotwhale.html',
#  'seagoddess.html',
#  'goldspotgoby.html',
#  'gnathophyllumamericanum.html',
#  'quillfin.html',
#  'venusseafan.html',
#  'meshfan.html',
#  'commonfan.html',
#  'fairybasslet.html',
#  'blackcapbasslet.html',
#  'featherhydroid.html',
#  'greenmoray.html',
#  'goldentailmoray.html',
#  'spottedmoray.html',
#  'purplemouthmoray.html',
#  'whitemargate.html',
#  'tomtate.html',
#  'caesargrunt.html',
#  'frenchgrunt.html',
#  'spanishgrunt.html',
#  'cottonwick.html',
#  'sailorchoice.html',
#  'whitegrunt.html',
#  'bluestripedgrunt.html',
#  'slipperydick.html',
#  'yellowcheekwrasse.html',
#  'yellowheadwrasse.html',
#  'clownwrasse.html',
#  'rainbowwrasse.html',
#  'blackearwrasse.html',
#  'puddingwife.html',
#  'largeleafvine.html',
#  'starencrustingsponge.html',
#  'sunraylettucecoral.html',
#  'ballyhoo.html',
#  'fireworm.html',
#  'browngardeneel.html',
#  'glasseye.html',
#  'caribbeanwhiptailstingray.html',
#  'hippocampuserectus.html',
#  'longsnoutseahorse.html',
#  'blueangel.html',
#  'queenangel.html',
#  'rockbeauty.html',
#  'squirrel.html',
#  'longspinesquirrel.html',
#  'floridaseacucumber.html',
#  'donkeycucumber.html',
#  'tigertailcucumber.html',
#  'hydatinaphysis.html',
#  'hydrozoanthustunicans.html',
#  'yellowbellyhamlet.html',
#  'yellowtailhamlet.html',
#  'bluehamlet.html',
#  'shyhamlet.html',
#  'indigohamlet.html',
#  'blackhamlet.html',
#  'barredhamlet.html',
#  'tanhamlet.html',
#  'hamlethyb.html',
#  'butterhamlet.html',
#  'hypselodorismarci.html',
#  'ruffledfeather.html',
#  'deepwaterfan.html',
#  'boga.html',
#  'greenfinger.html',
#  'irciniacampana.html',
#  'stinkersponge.html',
#  'blackball.html',
#  'iridopagurusreticulatus.html',
#  'iridopagurussp1.html',
#  'tubeanemone.html',
#  'flattreeoyster.html',
#  'roughstarcoral.html',
#  'threerowedcucumber.html',
#  'janiceaantiguensis.html',
#  'redbandedlobster.html',
#  'kyphosuscinerascens.html',
#  'chub.html',
#  'kyphosusvaigiensis.html',
#  'labrisomusconditus.html',
#  'labrisomuscricota.html',
#  'hairyblenny.html',
#  'hogfish.html',
#  'spottedtrunk.html',
#  'buffalotrunkfish.html',
#  'smoothtrunk.html',
#  'knobbyanemone.html',
#  'lebruniacoralligens.html',
#  'branchinganemone.html',
#  'whitecrypticsponge.html',
#  'wartycombjelly.html',
#  'antilleanfileclam.html',
#  'horseshoecrab.html',
#  'seathimblejellyfish.html',
#  'candybasslet.html',
#  'peppermintbasslet.html',
#  'starsnail.html',
#  'encrustingfanleaf.html',
#  'medusaworm.html',
#  'lolligunculabrevis.html',
#  'arrowblenny.html',
#  'luidiaalternata.html',
#  'muttonsnapper.html',
#  'schoolmaster.html',
#  'blackfinsnapper.html',
#  'cuberasnapper.html',
#  'graysnapper.html',
#  'dogsnapper.html',
#  'mahogany.html',
#  'lanesnapper.html',
#  'lygdamiswirtzi.html',
#  'lysiosquillinaglabriuscula.html',
#  'lysiosquillascabricauda.html',
#  'scarletshrimp.html',
#  'lysmatapederseni.html',
#  'variegatedurchin.html',
#  'lytechinuswilliamsi.html',
#  'macrocoelomatrispinosum.html',
#  'stingingbushhydroid.html',
#  'whitestinger.html',
#  'milkconch.html',
#  'macrotritopusdefilippi.html',
#  'tenraystarcoral.html',
#  'yellowpencil.html',
#  'sandtile.html',
#  'goldlineblenny.html',
#  'diamondblenny.html',
#  'saddledblenny.html',
#  'rosecoral.html',
#  'giantmanta.html',
#  'whitevalleymazecoral.html',
#  'mazecoral.html',
#  'shyfeatherduster.html',
#  'tarpon.html',
#  'melanellahypsela.html',
#  'blackdurgon.html',
#  'menippemercenaria.html',
#  'menippenodifrons.html',
#  'redhearturchin.html',
#  'carribeanvelvetshrimp.html',
#  'micrognathuscrinitus.html',
#  'yellowtaildamsel.html',
#  'bladefirecoral.html',
#  'branchingfire.html',
#  'redridgedclingingcrab.html',
#  'bandedclingingcrab.html',
#  'mithraxhispidus.html',
#  'channelcrab.html',
#  'fringedfilefish.html',
#  'slenderfile.html',
#  'redencrustingsponge.html',
#  'pinklumpysponge.html',
#  'greatstarcoral.html',
#  'yellowgoat.html',
#  'munidapusilla.html',
#  'spinyflowercoral.html',
#  'orangeicingsponge.html',
#  'strawberrysponge.html',
#  'knobbycactus.html',
#  'roughcactuscoral.html',
#  'ridgedcactus.html',
#  'blackgrouper.html',
#  'yellowmouthgrouper.html',
#  'tiger.html',
#  'yellowfingrouper.html',
#  'sharptaileel.html',
#  'goldspottedeel.html',
#  'blackbarsoldier.html',
#  'Mysidiumspp.html',
#  'aglajafelis.html',
#  'lesserray.html',
#  'lemonshark.html',
#  'bwcrinoid.html',
#  'touchmenot.html',
#  'darkmantis.html',
#  'longjawsquirrel.html',
#  'neslongus.html',
#  'pinkvase.html',
#  'lavenderropespounge.html',
#  'brownfanworm.html',
#  'yellowfanworm.html',
#  'roughtubesponge.html',
#  'reefoctopus.html',
#  'octopusmacropus.html',
#  'commonoctopus.html',
#  'diffuseivorybushcoral.html',
#  'yellowtailsnapper.html',
#  'ogcocephalusnasutus.html',
#  'olivareticularis.html',
#  'ophichthusophis.html',
#  'cometstar.html',
#  'redlipblenny.html',
#  'bluntspinedbrittlestar.html',
#  'spinybrittlestar.html',
#  'circlemarkedbrittlestar.html',
#  'ophiodermaphoenium.html',
#  'rubybrittlestar.html',
#  'reticulatedbrittlestar.html',
#  'ophiopsilariisei.html',
#  'ophiothrixoerstedii.html',
#  'spongebrittlestar.html',
#  'jawfish.html',
#  'bandedjawfish.html',
#  'duskyjawfish.html',
#  'lobedstarcoral.html',
#  'mountainousstarcoral.html',
#  'boulderstarcoral.html',
#  'seastar.html',
#  'leafyrolledblade.html',
#  'whitescrollalga.html',
#  'redreefhermit.html',
#  'paguristeserythrops.html',
#  'speckeledhermit.html',
#  'blueeyehermitcrab.html',
#  'shortfingerhermit.html',
#  'whiteencrustingzoanthid.html',
#  'pandarosacanthifolium.html',
#  'lobster.html',
#  'spottedlobster.html',
#  'parablenniusmarmoreus.html',
#  'creolefish.html',
#  'goldenzoanthid.html',
#  'highhat.html',
#  'parequesumbrosus.html',
#  'sculpturedslipperlobster.html',
#  'peliamutica.html',
#  'peliarotunda.html',
#  'glassysweeper.html',
#  'penicilluspyriformis.html',
#  'christmastreehydroid.html',
#  'nimblespraycrab.html',
#  'periclimenescfmeyeri.html',
#  'periclimenesiridescens.html',
#  'sunanemoneshrimp.html',
#  'spottedcleanershrimp.html',
#  'gianthermit.html',
#  'petrolisthesamoenus.html',
#  'burgundycrustalgae.html',
#  'polkadottedhermitcrab.html',
#  'phimochirusrandalli.html',
#  'phoronisaustralis.html',
#  'phylliroebucephalum.html',
#  'beadedanemone.html',
#  'pickfordiateuthispulchella.html',
#  'amberpenshell.html',
#  'tidalspraycrab.html',
#  'viscoussponge.html',
#  'plakortishalichondrioides.html',
#  'platypodiellaspectabilis.html',
#  'bentsearod.html',
#  'blacksearod.html',
#  'slitporesearod.html',
#  'gianttunicate.html',
#  'polycerasp1.html',
#  'grayangel.html',
#  'frenchangel.html',
#  'horseshoeworm.html',
#  'mustardhill.html',
#  'thinfingercoral.html',
#  'branchedfingercoral.html',
#  'fingercoral.html',
#  'sargassumswimmingcrab.html',
#  'priacanthusarenatus.html',
#  'rustygoby.html',
#  'longsnoutbutter.html',
#  'pseudoceroscrozieri.html',
#  'redspottedhorseshoeworm.html',
#  'poroussearods.html',
#  'leopardflatworm.html',
#  'symmetricalbrain.html',
#  'pseudopontonidesprincipis.html',
#  'pseudosquillaciliata.html',
#  'hiddenseacucumber.html',
#  'spottedgoat.html',
#  'wingoyster.html',
#  'angularseawhip.html',
#  'groovedbladeseawhip.html',
#  'commonlionfish.html',
#  'ptilocauliswalpersi.html',
#  'pyrosomaatlanticum.html',
#  'whitefanbryozoan.html',
#  'whaleshark.html',
#  'pinecone.html',
#  'rhizosmiliamaculata.html',
#  'wartycorallimorph.html',
#  'reeftunicate.html',
#  'floridacorallimorph.html',
#  'tuskedgoby.html',
#  'freckledsoapfish.html',
#  'greatersoapfish.html',
#  'rypticussubbifrenatus.html',
#  'magnificentfeatherduster.html',
#  'seafrost.html',
#  'salpamaxima.html',
#  'pelagictunicate.html',
#  'sanopusastrifer.html',
#  'splendidtoad.html',
#  'sargassumseaweed.html',
#  'whiteveinsargassum.html',
#  'reefsquirrel.html',
#  'duskysquirrel.html',
#  'midnightparrot.html',
#  'blueparrot.html',
#  'rainbowparrot.html',
#  'stripedparrotfish.html',
#  'princessparrot.html',
#  'queenparrot.html',
#  'diskcoral.html',
#  'atlanticmushroomcoral.html',
#  'cero.html',
#  'orangelumpyencrustingsponge.html',
#  'scorpaenaalbifimbria.html',
#  'scorpaenagrandicornis.html',
#  'mushroomscorpionfish.html',
#  'scorpion.html',
#  'reefscorpionfish.html',
#  'spanishlobster.html',
#  'reefsquid.html',
#  'almacojack.html',
#  'lanternbass.html',
#  'serranussubligarius.html',
#  'tobacco.html',
#  'harlequinbass.html',
#  'chalkbass.html',
#  'branchinghydroid.html',
#  'lesserstarletcoral.html',
#  'massivestarlet.html',
#  'variableboring.html',
#  'smenospongiaconulosa.html',
#  'smoothstarcoral.html',
#  'greenblotchparrotfish.html',
#  'redbandparrot.html',
#  'redtailparrot.html',
#  'yellowtailparrot.html',
#  'stoplightparrotfish.html',
#  'loggerheadsponge.html',
#  'bandtailpuffer.html',
#  'checkeredpuffer.html',
#  'barracuda.html',
#  'pinkredencrusting.html',
#  'spirastrellahartmani.html',
#  'spirobranchusgiganteus.html',
#  'thornyoyster.html',
#  'duskydamsel.html',
#  'longfindamselfish.html',
#  'beaugregory.html',
#  'bicolordamsel.html',
#  'threespotdamsel.html',
#  'cocoadamselfish.html',
#  'spinnerdolphin.html',
#  'slenderchiton.html',
#  'coralshrimp.html',
#  'goldencoralshrimp.html',
#  'arrowcrab.html',
#  'blushingstarcoral.html',
#  'sunanemone.html',
#  'wirecoral.html',
#  'strombusalatus.html',
#  'redfinneedlefish.html',
#  'roselace.html',
#  'volcanosponge.html',
#  'channelflounder.html',
#  'symphurusdiomedeanus.html',
#  'encrustingsocialtunicates.html',
#  'sanddiver.html',
#  'bluestripedlizardfish.html',
#  'clubtippedanemone.html',
#  'bluehead.html',
#  'caribbeansquatshrimp.html',
#  'thuridillapicta.html',
#  'algaehydroid.html',
#  'tigrigobiusharveyi.html',
#  'greenbandedgoby.html',
#  'topsentiaophiraphidites.html',
#  'permit.html',
#  'palometa.html',
#  'trachycarisrugosa.html',
#  'bleedingteethbryozoan.html',
#  'westindianmanatee.html',
#  'overgrowingmattunicate.html',
#  'westindianseaegg.html',
#  'tritoniabayeri.html',
#  'orangecupcoral.html',
#  'turbinellaangulata.html',
#  'dolphin.html',
#  'mermaidsfan.html',
#  'mottledmojarra.html',
#  'spongezoanthid.html',
#  'yellowray.html',
#  'seapearls.html',
#  'nettedbarrel.html',
#  'verongulareiswigi.html',
#  'pittedsponge.html',
#  'pinkbushalga.html',
#  'sargassumtrigger.html',
#  'giantbarrel.html',
#  'xestospongiarosariensis.html',
#  'rosyrazorfish.html',
#  'pearlyrazorfish.html',
#  'greenrazor.html',
#  'matzoanthid.html']

# %%
reefguide_hrefs_fish = ['flatneedle.html',
 'sergeantmajor.html',
 'nightsergeant.html',
 'roughheadblenny.html',
 'secretaryblenny.html',
 'spinyheadblenny.html',
 'honeycomb.html',
 'scrawledcowfish.html',
 'surgeonfish.html',
 'doctorfish.html',
 'bluetang.html',
 'eagleray.html',
 'bonefish.html',
 'scrawledfile.html',
 'hawkfish.html',
 'pipehorse.html',
 'blackmargate.html',
 'porkfish.html',
 'whitestarcardinalfish.html',
 'apogonbinotatus.html',
 'whitestarcardinalfish.html',
 'flamefish.html',
 'palecardinalfish.html',
 'apogonpseudomaculatus.html',
 'apogonrobinsi.html',
 'beltedcardinalfish.html',
 'sheepshead.html',
 'redfinneedlefish.html',
 'channelflounder.html',
 'symphurusdiomedeanus.html',
 'sanddiver.html',
 'bluestripedlizardfish.html',
 'bluehead.html',
 'tigrigobiusharveyi.html',
 'greenbandedgoby.html',
 'permit.html',
 'palometa.html',
 'westindianmanatee.html',
 'dolphin.html',
 'mottledmojarra.html',
 'yellowray.html',
 'sargassumtrigger.html',
 'rosyrazorfish.html',
 'pearlyrazorfish.html',
 'greenrazor.html',
]

# %%
len(reefguide_hrefs_fish)
# Out:
# 290

# %%
reefguide_hrefs_NotFish = [ species for species in ref_lst if species not in reefguide_hrefs_fish]

# %%
print(len(ref_lst))
print(len(reefguide_hrefs_NotFish))
# Out:
# 685
# 396

# %%
396 + 290
# Out:
# 686

# %%
len(set(reefguide_hrefs_fish)) == len(reefguide_hrefs_fish)
# Out:
# False

# %%
reefguide_hrefs_fish = list(set(reefguide_hrefs_fish))

# %%
fish_refs_DF = pd.DataFrame(data = reefguide_hrefs_fish)
notFish_refs_DF = pd.DataFrame(data = reefguide_hrefs_NotFish)
fish_refs_DF
# Out:
#                          0
# 0        slipperydick.html
# 1    freckledsoapfish.html
# 2          giantmanta.html
# 3     apogonbinotatus.html
# 4            mahogany.html
# ..                     ...
# 284     redtailparrot.html
# 285        cottonwick.html
# 286  palecardinalfish.html
# 287       caesargrunt.html
# 288       reefoctopus.html
#
# [289 rows x 1 columns]

# %%
fish_refs_DF.to_pickle('./files/reefguide_refs_fish.pkl')
notFish_refs_DF.to_pickle('./files/reefguide_refs_notFish.pkl')

# %% [markdown]
# Okay! Now is the moment of truth.. lets scrape info and images for all the refs we have for fish species.

# %%
columns = [ 'scientific_name', 'scientific_family', 'common_name', 'common_family', 'size_range_cm', 'depth_range_m', 'geodist' ]
reefguide_fish_DF = pd.DataFrame(columns = columns)

for species in reefguide_hrefs_fish:

    species_info = reefguide_scrape(species,1)

    reefguide_fish_DF.loc[len(reefguide_fish_DF)] = species_info
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 6
#       2 reefguide_fish_DF = pd.DataFrame(columns = columns)
#       4 for species in reefguide_hrefs_fish:
# ----> 6     species_info = reefguide_scrape(species,1)
#       8     reefguide_fish_DF.loc[len(reefguide_fish_DF)] = species_info
#
# Cell In[48], line 36, in reefguide_scrape(species_suffix, download_flag)
#      34     size_idx_start = details[7].find('(') + 1
#      35     size_idx_end = details[7].find(')') - 3
# ---> 36     size_range_cm = tuple(map(float,details[7][size_idx_start:size_idx_end].split()[0:3:2]))
#      37 else:
#      38     size_idx_start = details[7].find('(') + 1
#
# ValueError: could not convert string to float: 'to'

# %%
reefguide_fish_DF
# Out:
#             scientific_name scientific_family             common_name  \
# 0    Halichoeres bivittatus          Labridae           Slippery Dick
# 1     Rypticus bistrispinus        Serranidae       Freckled Soapfish
# 2           Manta birostris      Myliobatidae         Giant Manta Ray
# 3          Apogon binotatus        Apogonidae     Barred Cardinalfish
# 4         Lutjanus mahogoni        Lutjanidae        Mahogany Snapper
# 5         Lutjanus synagris        Lutjanidae            Lane Snapper
# 6            Synodus saurus      Synodontidae  Bluestriped Lizardfish
# 7        Trichechus manatus      Trichechidae     West Indian Manatee
# 8   Halichoeres maculipinna          Labridae            Clown Wrasse
# 9      Holacanthus ciliaris     Pomacanthidae         Queen Angelfish
# 10    Haemulon aurolineatum        Haemulidae                 Tomtate
# 11            Scarus vetula          Scaridae        Queen Parrotfish
# 12   Haemulon flavolineatum        Haemulidae            French Grunt
# 13     Malacanthus plumieri     Malacanthidae           Sand Tilefish
# 14         Ophichthus ophis      Ophichthidae       Spotted Snake Eel
#
#      common_family   size_range_cm depth_range_m  \
# 0          Wrasses    (12.0, 20.0)   (2.0, 12.0)
# 1       Soapfishes     (7.5, 13.0)   (3.0, 21.0)
# 2       Manta Rays  (180.0, 700.0)   (0.0, 12.0)
# 3   Cardinalfishes         (10.0,)   (1.0, 45.0)
# 4         Snappers    (18.0, 30.0)   (6.0, 18.0)
# 5         Snappers    (20.0, 30.0)   (2.0, 40.0)
# 6     Lizardfishes    (10.0, 18.0)   (0.0, 12.0)
# 7         Manatees        (400.0,)    (0.0, 3.0)
# 8          Wrasses     (7.0, 12.0)   (3.0, 12.0)
# 9      Angelfishes    (20.0, 35.0)   (6.0, 25.0)
# 10          Grunts    (12.0, 20.0)   (2.0, 20.0)
# 11    Parrotfishes    (30.0, 60.0)   (3.0, 25.0)
# 12          Grunts    (15.0, 25.0)   (3.0, 18.0)
# 13      Tilefishes    (30.0, 45.0)   (6.0, 21.0)
# 14      Snake Eels        (100.0,)   (1.0, 12.0)
#
#                                               geodist
# 0   [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 1         [Caribbean, Bahamas, South Florida, Brazil]
# 2                                    [Circumtropical]
# 3                 [Caribbean, Bahamas, South Florida]
# 4       [Caribbean, Bahamas, Florida, Gulf of Mexico]
# 5   [Caribbean, Bahamas, Florida, Gulf of Mexico, ...
# 6                                [Caribbean, Bahamas]
# 7                        [Florida, Caribbean, Brazil]
# 8      [Florida, Caribbean, Bahamas, Bermuda, Brazil]
# 9   [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 10             [Caribbean, Bahamas, Florida, Bermuda]
# 11             [Caribbean, Bahamas, Florida, Bermuda]
# 12  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 13  [Caribbean, Bahamas, Florida, Gulf of Mexico, ...
# 14                      [Florida, Bahamas, Caribbean]

# %%
reefguide_hrefs_fish[15]
# Out:
# 'tarpon.html'

# %% [markdown]
# It appears I need to fix a bug with how the sizes are grabbed. After much work and testing with cases below, I have created a generic handler that will interpret strings with ranges in a number of different formats found on the website. It should work for both depth and size. However I should note that it will return the range in cm, so for depth we will need to convert to m

# %%
case1 = 'Up to 13 ft. (4 m)'
case2 = 'Up to 4 in. (10 cm)'
case3 = '3 - 10 ft. (1 to 3 m)'
case4 = '0 - 1 ft. (10 to 100 cm)'
case5 = '2 - 5 ft. (60 cm to 1.5 m)'
case6 = '1 - 4 ft.'
case7 = '0.25-1 in.'
case8 = 'Up to 5 in.'

tests = [ case1, case2, case3, case4, case5, case6, case7, case8 ]

for test in tests:

    range_idx_start = test.find('(') + 1
    range_idx_end = test.find(')')

    if range_idx_end == -1:
        inside_parens = test
    else:
        inside_parens = test[range_idx_start:range_idx_end]
    contents_list = inside_parens.split()
    print(contents_list)
# Out:
# ['4', 'm']
# ['10', 'cm']
# ['1', 'to', '3', 'm']
# ['10', 'to', '100', 'cm']
# ['60', 'cm', 'to', '1.5', 'm']
# ['1', '-', '4', 'ft.']
# ['0.25-1', 'in.']
# ['Up', 'to', '5', 'in.']

# %%
def range_handler(range_details):
    
    range_idx_start = range_details.find('(') + 1
    range_idx_end = range_details.find(')')

    if range_idx_end == -1:
        inside_parens = range_details
    else:
        inside_parens = range_details[range_idx_start:range_idx_end]
    contents_list = inside_parens.split()

    if len(contents_list[0].split('-')) > 1:
        contents_list = contents_list[0].split('-')+[contents_list[1]]
    elif 'Up' in contents_list:
        contents_list = contents_list[2:]

    if len(contents_list) == 2:
        if 'in.' in contents_list:
            range_in = [0,contents_list[0]]
            range_in = np.array(list(map(float,range_in)))
            range_cm = tuple(np.round(range_in * 2.54))
        elif 'ft.' in contents_list:
            range_ft = [0,contents_list[0]]
            range_ft = np.array(list(map(float,range_ft)))
            range_cm = tuple(np.round(range_ft * 12 * 2.54))
        elif 'm' in contents_list:
            range_m = [0,contents_list[0]]
            range_m = np.array(list(map(float,range_m)))
            range_cm = tuple(range_m * 100)
        else:
            range_cm = tuple(map(float,[0, contents_list[0]]))
    elif len(contents_list) == 3:
        if 'in.' in contents_list:
            range_in = [contents_list[0],contents_list[1]]
            range_in = np.array(list(map(float,range_in)))
            range_cm = tuple(np.round(range_in * 2.54))
        elif 'ft.' in contents_list:
            range_ft = [contents_list[0],contents_list[1]]
            range_ft = np.array(list(map(float,range_ft)))
            range_cm = tuple(np.round(range_ft * 12 * 2.54))
        elif 'm' in contents_list:
            range_m = [contents_list[0],contents_list[1]]
            range_m = np.array(list(map(float,range_m)))
            range_cm = tuple(range_m * 100)
        else:
            range_cm = tuple(map(float,[contents_list[0],contents_list[1]]))
    elif len(contents_list) == 4:
        if 'in.' in contents_list:
            range_in = [contents_list[0],contents_list[2]]
            range_in = np.array(list(map(float,range_in)))
            range_cm = tuple(np.round(range_in * 2.54))
        elif 'ft.' in contents_list:
            range_ft = [contents_list[0],contents_list[2]]
            range_ft = np.array(list(map(float,range_ft)))
            range_cm = tuple(np.round(range_ft * 12 * 2.54))
        elif 'm' in contents_list:
            range_m = [contents_list[0],contents_list[2]]
            range_m = np.array(list(map(float,range_m)))
            range_cm = tuple(range_m * 100)
        else:
            range_cm = tuple(map(float,[contents_list[0],contents_list[2]]))
    else:
        lower = float(contents_list[0])
        higher = float(contents_list[3])
        if contents_list[1] == 'in.':
            range_cm = (lower * 2.54, higher * 12 * 2.54)
        else:
            range_cm = (lower, higher * 100)

    return range_cm

# %% [markdown]
# Okay! Should be better.. lets try again.

# %%
columns = [ 'scientific_name', 'scientific_family', 'common_name', 'common_family', 'range_cm', 'depth_range_m', 'geodist' ]
reefguide_fish_DF = pd.DataFrame(columns = columns)

for species in reefguide_hrefs_fish[0:20]:

    species_info = reefguide_scrape(species,1)

    reefguide_fish_DF.loc[len(reefguide_fish_DF)] = species_info

# %%
reefguide_fish_DF
# Out:
#                 scientific_name scientific_family             common_name  \
# 0        Halichoeres bivittatus          Labridae           Slippery Dick
# 1         Rypticus bistrispinus        Serranidae       Freckled Soapfish
# 2               Manta birostris      Myliobatidae         Giant Manta Ray
# 3              Apogon binotatus        Apogonidae     Barred Cardinalfish
# 4             Lutjanus mahogoni        Lutjanidae        Mahogany Snapper
# 5             Lutjanus synagris        Lutjanidae            Lane Snapper
# 6                Synodus saurus      Synodontidae  Bluestriped Lizardfish
# 7            Trichechus manatus      Trichechidae     West Indian Manatee
# 8       Halichoeres maculipinna          Labridae            Clown Wrasse
# 9          Holacanthus ciliaris     Pomacanthidae         Queen Angelfish
# 10        Haemulon aurolineatum        Haemulidae                 Tomtate
# 11                Scarus vetula          Scaridae        Queen Parrotfish
# 12       Haemulon flavolineatum        Haemulidae            French Grunt
# 13         Malacanthus plumieri     Malacanthidae           Sand Tilefish
# 14             Ophichthus ophis      Ophichthidae       Spotted Snake Eel
# 15          Megalops atlanticus       Megalopidae         Atlantic Tarpon
# 16   Acanthostracion polygonius       Ostraciidae       Honeycomb Cowfish
# 17        Coryphopterus eidolon          Gobiidae             Pallid Goby
# 18  Mycteroperca interstitialis        Serranidae     Yellowmouth Grouper
# 19              Gramma melacara       Grammatidae        Blackcap Basslet
#
#      common_family        range_cm  depth_range_m  \
# 0          Wrasses    (12.0, 20.0)    (2.0, 12.0)
# 1       Soapfishes     (7.5, 13.0)    (3.0, 21.0)
# 2       Manta Rays  (180.0, 700.0)    (0.0, 12.0)
# 3   Cardinalfishes     (0.0, 10.0)    (1.0, 45.0)
# 4         Snappers    (18.0, 30.0)    (6.0, 18.0)
# 5         Snappers    (20.0, 30.0)    (2.0, 40.0)
# 6     Lizardfishes    (10.0, 18.0)    (0.0, 12.0)
# 7         Manatees    (0.0, 400.0)     (0.0, 3.0)
# 8          Wrasses     (7.0, 12.0)    (3.0, 12.0)
# 9      Angelfishes    (20.0, 35.0)    (6.0, 25.0)
# 10          Grunts    (12.0, 20.0)    (2.0, 20.0)
# 11    Parrotfishes    (30.0, 60.0)    (3.0, 25.0)
# 12          Grunts    (15.0, 25.0)    (3.0, 18.0)
# 13      Tilefishes    (30.0, 45.0)    (6.0, 21.0)
# 14      Snake Eels    (0.0, 100.0)    (1.0, 12.0)
# 15         Tarpons   (60.0, 150.0)    (0.0, 12.0)
# 16       Boxfishes    (18.0, 38.0)    (6.0, 25.0)
# 17          Gobies      (2.5, 5.0)    (6.0, 27.0)
# 18        Groupers    (30.0, 60.0)    (3.0, 25.0)
# 19        Basslets      (5.0, 8.0)  (18.0, 120.0)
#
#                                               geodist
# 0   [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 1         [Caribbean, Bahamas, South Florida, Brazil]
# 2                                    [Circumtropical]
# 3                 [Caribbean, Bahamas, South Florida]
# 4       [Caribbean, Bahamas, Florida, Gulf of Mexico]
# 5   [Caribbean, Bahamas, Florida, Gulf of Mexico, ...
# 6                                [Caribbean, Bahamas]
# 7                        [Florida, Caribbean, Brazil]
# 8      [Florida, Caribbean, Bahamas, Bermuda, Brazil]
# 9   [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 10             [Caribbean, Bahamas, Florida, Bermuda]
# 11             [Caribbean, Bahamas, Florida, Bermuda]
# 12  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 13  [Caribbean, Bahamas, Florida, Gulf of Mexico, ...
# 14                      [Florida, Bahamas, Caribbean]
# 15             [Caribbean, Bahamas, Florida, Bermuda]
# 16     [Caribbean, Bahamas, Florida, Bermuda, Brazil]
# 17  [Caribbean, Bahamas, South Florida, Gulf of Me...
# 18  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 19   [Southern Caribbean, Western Caribbean, Bahamas]

# %% [markdown]
# Yay! I think its working. Let's let it rip for the whole ref_list so I can have it done.

# %%
columns = [ 'scientific_name', 'scientific_family', 'common_name', 'common_family', 'size_range_cm', 'depth_range_m', 'geodist' ]
reefguide_fish_DF = pd.DataFrame(columns = columns)

for species in reefguide_hrefs_fish:

    species_info = reefguide_scrape(species,1)

    reefguide_fish_DF.loc[len(reefguide_fish_DF)] = species_info

# %%
reefguide_fish_DF
# Out:
#             scientific_name scientific_family             common_name  \
# 0    Halichoeres bivittatus          Labridae           Slippery Dick
# 1     Rypticus bistrispinus        Serranidae       Freckled Soapfish
# 2           Manta birostris      Myliobatidae         Giant Manta Ray
# 3          Apogon binotatus        Apogonidae     Barred Cardinalfish
# 4         Lutjanus mahogoni        Lutjanidae        Mahogany Snapper
# ..                      ...               ...                     ...
# 284  Sparisoma chrysopterum          Scaridae      Redtail Parrotfish
# 285      Haemulon melanurum        Haemulidae              Cottonwick
# 286       Apogon planifrons        Apogonidae       Pale Cardinalfish
# 287    Haemulon carbonarium        Haemulidae            Caesar Grunt
# 288        Octopus briareus       Octopodidae  Caribbean Reef Octopus
#
#       common_family   size_range_cm depth_range_m  \
# 0           Wrasses    (12.0, 20.0)   (2.0, 12.0)
# 1        Soapfishes     (7.5, 13.0)   (3.0, 21.0)
# 2        Manta Rays  (180.0, 700.0)   (0.0, 12.0)
# 3    Cardinalfishes     (0.0, 10.0)   (1.0, 45.0)
# 4          Snappers    (18.0, 30.0)   (6.0, 18.0)
# ..              ...             ...           ...
# 284    Parrotfishes    (35.0, 40.0)   (2.0, 12.0)
# 285          Grunts    (17.0, 25.0)   (3.0, 15.0)
# 286  Cardinalfishes     (3.0, 10.0)   (3.0, 30.0)
# 287          Grunts    (18.0, 30.0)   (3.0, 15.0)
# 288       Octopuses    (30.0, 60.0)   (5.0, 23.0)
#
#                                                geodist
# 0    [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 1          [Caribbean, Bahamas, South Florida, Brazil]
# 2                                     [Circumtropical]
# 3                  [Caribbean, Bahamas, South Florida]
# 4        [Caribbean, Bahamas, Florida, Gulf of Mexico]
# ..                                                 ...
# 284             [Caribbean, Bahamas, Florida, Bermuda]
# 285  [Caribbean, Florida, Bahamas, Bermuda, Brazil,...
# 286        [Caribbean, Bahamas, South Florida, Brazil]
# 287             [Caribbean, Bahamas, Florida, Bermuda]
# 288                      [Caribbean, Bahamas, Florida]
#
# [289 rows x 7 columns]

# %%
reefguide_fish_DF.to_pickle('./files/fishspecies_reefguide_info.pkl')

# %%
reefguide_hrefs_fish[188]
# Out:
# 'peppermintgoby.html'

# %%
reefguide_fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 288
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    289 non-null    object
#  1   scientific_family  289 non-null    object
#  2   common_name        289 non-null    object
#  3   common_family      289 non-null    object
#  4   size_range_cm      289 non-null    object
#  5   depth_range_m      289 non-null    object
#  6   geodist            289 non-null    object
# dtypes: object(7)
# memory usage: 18.1+ KB

# %%
cat_columns = [ 'scientific_family', 'common_family']
for column in cat_columns:
    print('====================================================')
    print(reefguide_fish_DF[column].value_counts())
# Out:
# ====================================================
# Serranidae        32
# Gobiidae          22
# Labridae          15
# Pomacentridae     13
# Haemulidae        12
#                   ..
# Congridae          1
# Ogcocephalidae     1
# Raspailiidae       1
# Torpedinidae       1
# Megalopidae        1
# Name: scientific_family, Length: 72, dtype: int64
# ====================================================
# Gobies                 22
# Wrasses                15
# Grunts                 12
# Parrotfishes           11
# Hamlets                10
#                        ..
# Cornetfishes            1
# Sweepers                1
# Mackerels and Tunas     1
# Eagle Rays              1
# Bonnetmouths            1
# Name: common_family, Length: 78, dtype: int64

# %% [markdown]
# ## Smithsonian Institute

# %% [markdown]
# I think we will scrape this one next. As it has a large database it should include most species as well as a number of images. So the plan is to build off our reefguide image and dataset, using our scientific_name as the key and to help look up the fish on this and other websites.

# %%
reefguide_fish_DF = pd.read_pickle('./files/fishspecies_reefguide_info.pkl')

# %%
reefguide_fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 288
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    289 non-null    object
#  1   scientific_family  289 non-null    object
#  2   common_name        289 non-null    object
#  3   common_family      289 non-null    object
#  4   size_range_cm      289 non-null    object
#  5   depth_range_m      289 non-null    object
#  6   geodist            289 non-null    object
# dtypes: object(7)
# memory usage: 18.1+ KB

# %%
reefguide_fish_DF.head()
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 1   Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2         Manta birostris      Myliobatidae      Giant Manta Ray
# 3        Apogon binotatus        Apogonidae  Barred Cardinalfish
# 4       Lutjanus mahogoni        Lutjanidae     Mahogany Snapper
#
#     common_family   size_range_cm depth_range_m  \
# 0         Wrasses    (12.0, 20.0)   (2.0, 12.0)
# 1      Soapfishes     (7.5, 13.0)   (3.0, 21.0)
# 2      Manta Rays  (180.0, 700.0)   (0.0, 12.0)
# 3  Cardinalfishes     (0.0, 10.0)   (1.0, 45.0)
# 4        Snappers    (18.0, 30.0)   (6.0, 18.0)
#
#                                              geodist
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 1        [Caribbean, Bahamas, South Florida, Brazil]
# 2                                   [Circumtropical]
# 3                [Caribbean, Bahamas, South Florida]
# 4      [Caribbean, Bahamas, Florida, Gulf of Mexico]

# %%
reefguide_fish_DF.scientific_name[0]
# Out:
# 'Halichoeres bivittatus'

# %%
reefguide_fish_DF.loc[reefguide_fish_DF.scientific_name == 'Acanthurus bahianus']
# Out:
#          scientific_name scientific_family        common_name  common_family  \
# 155  Acanthurus bahianus      Acanthuridae  Ocean Surgeonfish  Surgeonfishes
#
#     size_range_cm depth_range_m  \
# 155  (15.0, 30.0)   (5.0, 25.0)
#
#                                                geodist
# 155  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...

# %%
URL = 'https://biogeodb.stri.si.edu/caribbean/en/thefishes/systematic'
page = requests.get(URL)

smithsonian_soup = BeautifulSoup(page.content, "html.parser")

# %% [markdown]
# Okay so looking at the web page inspector, from the URL above we can get the href for all the species we currently have in our reefguide dataframe. Let's explore how to get the hrefs from the soup obj.

# %%
first_row = smithsonian_soup.find('a',{'style':'padding-left:80px;'})

# %%
print(first_row.prettify())
print(first_row.get_text())
# Out:
# <a class="internal" href="spe/5756" id="5756" style="padding-left:80px;">
#  Chiloscyllium punctatum
# </a>
# Chiloscyllium punctatum

# %%
all_entries = smithsonian_soup.find_all('a',{'style':'padding-left:80px;'})

# %%
all_entries[0:5]
# Out:
# [<a class="internal" href="spe/5756" id="5756" style="padding-left:80px;">Chiloscyllium punctatum</a>,
#  <a class="internal" href="spe/24" id="24" style="padding-left:80px;">Ginglymostoma cirratum</a>,
#  <a class="internal" href="spe/26" id="26" style="padding-left:80px;">Rhincodon typus</a>,
#  <a class="internal" href="spe/2674" id="2674" style="padding-left:80px;">Carcharias taurus</a>,
#  <a class="internal" href="spe/31" id="31" style="padding-left:80px;">Odontaspis ferox</a>]

# %%
reefguide_fish_DF.loc[reefguide_fish_DF.scientific_name == all_entries[1].get_text()]
# Out:
#             scientific_name   scientific_family  common_name common_family  \
# 169  Ginglymostoma cirratum  Ginglymostomatidae  Nurse Shark  Nurse Sharks
#
#       size_range_cm depth_range_m  \
# 169  (150.0, 350.0)   (4.0, 30.0)
#
#                                                geodist
# 169  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...

# %%
all_entries[1].get('href')
# Out:
# 'spe/24'

# %%
# get tuple of scientific name and species href for all species already in reefguide_df

reefguide_fish_DF['smithsonian_href'] = pd.Series(dtype = 'object')
for row in reefguide_fish_DF.iterrows():
    for entry in all_entries:
        if row[1].scientific_name == entry.get_text():
            row[1].smithsonian_href = entry.get('href')
            continue

# %%
reefguide_fish_DF.head()
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 1   Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2         Manta birostris      Myliobatidae      Giant Manta Ray
# 3        Apogon binotatus        Apogonidae  Barred Cardinalfish
# 4       Lutjanus mahogoni        Lutjanidae     Mahogany Snapper
#
#     common_family   size_range_cm depth_range_m  \
# 0         Wrasses    (12.0, 20.0)   (2.0, 12.0)
# 1      Soapfishes     (7.5, 13.0)   (3.0, 21.0)
# 2      Manta Rays  (180.0, 700.0)   (0.0, 12.0)
# 3  Cardinalfishes     (0.0, 10.0)   (1.0, 45.0)
# 4        Snappers    (18.0, 30.0)   (6.0, 18.0)
#
#                                              geodist smithsonian_href
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...         spe/3894
# 1        [Caribbean, Bahamas, South Florida, Brazil]         spe/3537
# 2                                   [Circumtropical]              NaN
# 3                [Caribbean, Bahamas, South Florida]         spe/3595
# 4      [Caribbean, Bahamas, Florida, Gulf of Mexico]         spe/3690

# %%
reefguide_fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 288
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    289 non-null    object
#  1   scientific_family  289 non-null    object
#  2   common_name        289 non-null    object
#  3   common_family      289 non-null    object
#  4   size_range_cm      289 non-null    object
#  5   depth_range_m      289 non-null    object
#  6   geodist            289 non-null    object
#  7   smithsonian_href   251 non-null    object
# dtypes: object(8)
# memory usage: 28.4+ KB

# %% [markdown]
# Hmm.. so already 38 species not found in the database. Let's see which ones

# %%
reefguide_fish_DF.loc[reefguide_fish_DF.smithsonian_href.isna() ]
# Out:
#                        scientific_name scientific_family  \
# 2                      Manta birostris      Myliobatidae
# 7                   Trichechus manatus      Trichechidae
# 29              Eretmochelys imbricata       Cheloniidae
# 41               Micrognathus crinitus      Syngnathidae
# 46             Isostichopus badionotus     Stichopodidae
# 65                  Elacatinus dilepis          Gobiidae
# 69                Stegastes variabilis     Pomacentridae
# 72                     Caretta caretta       Cheloniidae
# 78                   Carangoides ruber        Carangidae
# 82            Sargocentron vexillarium     Holocentridae
# 84                  Tursiops truncatus       Delphinidae
# 100                Holothuria mexicana     Holothuriidae
# 101               Narcine brasiliensis      Torpedinidae
# 106                  Ectyoplasia ferox      Raspailiidae
# 115        Kyphosus sectatrix/bigibbus        Kyphosinae
# 137  Coryphopterus personatus/hyalinus          Gobiidae
# 142                   Elactinus lobeli          Gobiidae
# 153           Carangoides bartholomaei        Carangidae
# 155                Acanthurus bahianus      Acanthuridae
# 158               Holothuria floridana     Holothuriidae
# 161                    Inermia vittata        Inermiidae
# 198                     Chelonia mydas       Cheloniidae
# 199              Stenella longirostris       Delphinidae
# 214          Amphelikturus dendriticus      Syngnathidae
# 215                     Ulaema lefroyi         Gerreidae
# 216                Himantura schmardae        Dasyatidae
# 221                 Dasyatis americana        Dasyatidae
# 225                 Holothuria thomasi     Holothuriidae
# 230            Emblemariopsis signifer      Chaenopsidae
# 232                   Hypoplectrus sp.        Serranidae
# 235                 Pseudothyone belli  Sclerodactylidae
# 244                   Octopus macropus       Octopodidae
# 245                Paranthias furcifer        Serranidae
# 250           Ophioblennius atlanticus        Blenniidae
# 265               Eostichopus arnesoni     Stichopodidae
# 270              Sargocentron coruscum     Holocentridae
# 272                   Octopus vulgaris       Octopodidae
# 288                   Octopus briareus       Octopodidae
#
#                          common_name       common_family   size_range_cm  \
# 2                    Giant Manta Ray          Manta Rays  (180.0, 700.0)
# 7                West Indian Manatee            Manatees    (0.0, 400.0)
# 29                  Hawksbill Turtle             Turtles   (30.0, 107.0)
# 41                Harlequin Pipefish          Pipefishes    (12.0, 20.0)
# 46          Three-Rowed Sea Cucumber       Sea Cucumbers    (25.0, 40.0)
# 65                  Orangesided Goby              Gobies      (1.2, 1.8)
# 69                  Cocoa Damselfish        Damselfishes     (8.0, 10.0)
# 72                 Loggerhead Turtle             Turtles   (30.0, 100.0)
# 78                          Bar Jack               Jacks    (20.0, 35.0)
# 82                Dusky Squirrelfish      Squirrelfishes     (8.0, 15.0)
# 84                Bottlenose Dolphin            Dolphins  (152.0, 366.0)
# 100         Donkey Dung Sea Cucumber       Sea Cucumbers    (25.0, 35.0)
# 101              Lesser Electric Ray       Electric Rays    (25.0, 45.0)
[Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 216    (0.0, 6.0)                              [Northwest Caribbean]
# 221   (0.0, 25.0)      [Caribbean, Bahamas, Florida, Gulf of Mexico]
# 225   (3.0, 30.0)                      [Caribbean, Bahamas, Florida]
# 230   (8.0, 30.0)                               [Bahamas, Caribbean]
# 232   (3.0, 25.0)                      [Caribbean, Bahamas, Florida]
# 235   (0.0, 37.0)       [Caribbean, Bahamas, South Florida, Bermuda]
# 244   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 245   (6.0, 50.0)  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 250   (0.0, 12.0)                      [Bahamas, Caribbean, Florida]
# 265   (8.0, 23.0)                       [Eastern Caribbean, Bahamas]
# 270   (2.0, 23.0)             [Caribbean, Bahamas, Florida, Bermuda]
# 272   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 288   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
#
#     smithsonian_href
# 2                NaN
# 7                NaN
# 29               NaN
# 41               NaN
# 46               NaN
# 65               NaN
# 69               NaN
# 72               NaN
# 78               NaN
# 82               NaN
# 84               NaN
# 100              NaN
# 101              NaN
# 106              NaN
# 115              NaN
# 137              NaN
# 142              NaN
# 153              NaN
# 155              NaN
# 158              NaN
# 161              NaN
# 198              NaN
# 199              NaN
# 214              NaN
# 215              NaN
# 216              NaN
# 221              NaN
# 225              NaN
# 230              NaN
# 232              NaN
# 235              NaN
# 244              NaN
# 245              NaN
# 250              NaN
# 265              NaN
# 270              NaN
# 272              NaN
# 288              NaN

# %% [markdown]
# Soooo I think we will eliminate a number of these that aren't fish for now, since I didn't really need to include them in the first place. For the ones that are fish, we will look them up and try and see if there are inconsistincies with scientific names or other issues that would lead to us removing the row altogether.

# %% [markdown]
# 1. Elacatinus dilepis --> According to fishbase.se, this is an outdated and invalid taxonomic identification. Replace with Tigrigobius dilepis
# 2. Stegastes variabilis	--> This is the correct name on fishbase, though it does have another entry for Stegastes xanthurus and they share the common name Cocoa Damselfish. Smithsonian uses that as well, so we will change it
# 3. Carangoides ruber --> fishbase says this is outdated, use Caranx ruber instead. Smithsonian agrees
# 4. Sargocentron vexillarium	--> fishbase and smithsonian say Neoniphon vexillarium
# 5. Kyphosus sectatrix/bigibbus	--> fishbase says bigibbus is a 'Brown Chub' endemic only to Pacific whereas sectatrix is know as the Bermuda sea chub found circumglobally
# 6. Coryphopterus personatus/hyalinus --> it seems like reefguide guy took the liberty of assuming that these are actually the same species. split this entry
# 7. Elactinus lobeli --> reefguide spelling mistake, should be Elacatinus
# 8. Carangoides bartholomaei	--> same as bar jack, should be Caranx not Carangoides
# 9. Acanthurus bahianus --> There seems to be argument over whether this is a distinct species from Acanthurus tractus, but since tractus is what smithsonian uses lets go with that
# 10. Inermia vittata	--> fishbase and smithsonian use Haemulon vittatum
# 11. Amphelikturus dendriticus --> fishbase thinks this is okay, smithsonian uses Acentronura dendritica which fishbase says is not the currently accepted name
# 12. Ulaema lefroyi --> fishbase likes, smithsonian uses outdated Eucinostomus lefroyi
# 13. Emblemariopsis signifer --> fishbase likes, smithsonian calls this the Caribbean Blenny, Emblemariopsis carib, which looks like a completely different fish on fishbase
# 14. Hypoplectrus sp. --> remove, this is a hybrid species
# 15. Paranthias furcifer --> fishbase likes, smithsonian uses dated Cephalopholis furcifer
# 16. Ophioblennius atlanticus --> fishbase likes, smithsonian uses Ophioblennius macclurei. Fishbase agrees this is also a species, and I think macclurei looks more like what I would choose for redlip blenny
# 17. Sargocentron coruscum --> fishbase likes, smithsonian uses Neoniphon coruscum, which fishbase says doesn't exist. A quick google search has me leaning toward Sargocentron coruscum
#
# So, for the ones reefguide clearly has wrong, we will modify those entries, remembering to check our image structure. For the ones smithsonian has wrong, we know what they use so we can create a little dictionary for replacement just during lookup. The rest we will remove the rows from reefguide_fish_DF for now.

# %%
reefguide_fish_DF.scientific_name.loc[65]
# Out:
# 'Elacatinus dilepis'

# %%
# items that just need renaming

reefguide_fish_DF.scientific_name.loc[65] = 'Tigrigobius dilepis'
reefguide_fish_DF.scientific_name.loc[69] = 'Stegastes xanthurus'
reefguide_fish_DF.scientific_name.loc[78] = 'Caranx ruber'
reefguide_fish_DF.scientific_name.loc[82] = 'Neoniphon vexillarium'
reefguide_fish_DF.scientific_name.loc[115] = 'Kyphosus sectatrix'
reefguide_fish_DF.common_name.loc[115] = 'Bermuda Chub'
reefguide_fish_DF.scientific_name.loc[142] = 'Elacatinus lobeli'
reefguide_fish_DF.scientific_name.loc[153] = 'Caranx bartholomaei'
reefguide_fish_DF.scientific_name.loc[155] = 'Acanthurus tractus'
reefguide_fish_DF.scientific_name.loc[161] = 'Haemulon vittatum'
reefguide_fish_DF.scientific_name.loc[250] = 'Ophioblennius macclurei'

# dictionary for when smithsonian is wrong

smith_interpreter = {'Amphelikturus dendriticus' : 'Acentronura dendritica',
                     'Ulaema lefroyi' : 'Eucinostomus lefroyi',
                     'Emblemariopsis signifer' : 'Emblemariopsis carib',
                     'Paranthias furcifer' : 'Cephalopholis furcifer',
                     'Sargocentron coruscum' : 'Neoniphon coruscum'}

# splitting random combined entry

reefguide_fish_DF.loc[289] = [ 'Coryphopterus hyalinus', reefguide_fish_DF.scientific_family.loc[137], 'Glass Goby', reefguide_fish_DF.common_family.loc[137], 
                               reefguide_fish_DF.size_range_cm.loc[137], reefguide_fish_DF.depth_range_m.loc[137], reefguide_fish_DF.geodist.loc[137], 
                               reefguide_fish_DF.smithsonian_href.loc[137] ]
reefguide_fish_DF.loc[137] = [ 'Coryphopterus personatus', reefguide_fish_DF.scientific_family.loc[137], 'Masked Goby', reefguide_fish_DF.common_family.loc[137], 
                               reefguide_fish_DF.size_range_cm.loc[137], reefguide_fish_DF.depth_range_m.loc[137], reefguide_fish_DF.geodist.loc[137], 
                               reefguide_fish_DF.smithsonian_href.loc[137] ]

# dropping hybrid species
# commenting because ran and index no longer exists
# reefguide_fish_DF.drop(index = 232, inplace = True)
# Out:
# c:\Users\esmba\miniconda3\envs\IDenv\lib\site-packages\numpy\core\fromnumeric.py:3156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim

# %%
reefguide_fish_DF.loc[reefguide_fish_DF.smithsonian_href.isna() ]
# Out:
#                scientific_name scientific_family  \
# 2              Manta birostris      Myliobatidae
# 7           Trichechus manatus      Trichechidae
# 29      Eretmochelys imbricata       Cheloniidae
# 41       Micrognathus crinitus      Syngnathidae
# 46     Isostichopus badionotus     Stichopodidae
# 65         Tigrigobius dilepis          Gobiidae
# 69         Stegastes xanthurus     Pomacentridae
# 72             Caretta caretta       Cheloniidae
# 78                Caranx ruber        Carangidae
# 82       Neoniphon vexillarium     Holocentridae
# 84          Tursiops truncatus       Delphinidae
# 100        Holothuria mexicana     Holothuriidae
# 101       Narcine brasiliensis      Torpedinidae
# 106          Ectyoplasia ferox      Raspailiidae
# 115         Kyphosus sectatrix        Kyphosinae
# 137   Coryphopterus personatus          Gobiidae
# 142          Elacatinus lobeli          Gobiidae
# 153        Caranx bartholomaei        Carangidae
# 155         Acanthurus tractus      Acanthuridae
# 158       Holothuria floridana     Holothuriidae
# 161          Haemulon vittatum        Inermiidae
# 198             Chelonia mydas       Cheloniidae
# 199      Stenella longirostris       Delphinidae
# 214  Amphelikturus dendriticus      Syngnathidae
# 215             Ulaema lefroyi         Gerreidae
# 216        Himantura schmardae        Dasyatidae
# 221         Dasyatis americana        Dasyatidae
# 225         Holothuria thomasi     Holothuriidae
# 230    Emblemariopsis signifer      Chaenopsidae
# 235         Pseudothyone belli  Sclerodactylidae
# 244           Octopus macropus       Octopodidae
# 245        Paranthias furcifer        Serranidae
# 250    Ophioblennius macclurei        Blenniidae
# 265       Eostichopus arnesoni     Stichopodidae
# 270      Sargocentron coruscum     Holocentridae
# 272           Octopus vulgaris       Octopodidae
# 288           Octopus briareus       Octopodidae
# 289     Coryphopterus hyalinus          Gobiidae
#
#                          common_name       common_family   size_range_cm  \
# 2                    Giant Manta Ray          Manta Rays  (180.0, 700.0)
# 7                West Indian Manatee            Manatees    (0.0, 400.0)
# 29                  Hawksbill Turtle             Turtles   (30.0, 107.0)
# 41                Harlequin Pipefish          Pipefishes    (12.0, 20.0)
# 46          Three-Rowed Sea Cucumber       Sea Cucumbers    (25.0, 40.0)
# 65                  Orangesided Goby              Gobies      (1.2, 1.8)
# 69                  Cocoa Damselfish        Damselfishes     (8.0, 10.0)
# 72                 Loggerhead Turtle             Turtles   (30.0, 100.0)
# 78                          Bar Jack               Jacks    (20.0, 35.0)
# 82                Dusky Squirrelfish      Squirrelfishes     (8.0, 15.0)
# 84                Bottlenose Dolphin            Dolphins  (152.0, 366.0)
# 100         Donkey Dung Sea Cucumber       Sea Cucumbers    (25.0, 35.0)
# 101              Lesser Electric Ray       Electric Rays    (25.0, 45.0)
# 106  Brown Encrusting Octopus Sponge      Common Sponges    (15.0, 40.0)
# 115                     Bermuda Chub               Chubs    (30.0, 60.0)
# 137                      Masked Goby              Gobies      (1.0, 3.0)
# 142              Caribbean Neon Goby              Gobies      (2.5, 4.0)
# 153                      Yellow Jack               Jacks    (30.0, 60.0)
[Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 216    (0.0, 6.0)                              [Northwest Caribbean]
# 221   (0.0, 25.0)      [Caribbean, Bahamas, Florida, Gulf of Mexico]
# 225   (3.0, 30.0)                      [Caribbean, Bahamas, Florida]
# 230   (8.0, 30.0)                               [Bahamas, Caribbean]
# 235   (0.0, 37.0)       [Caribbean, Bahamas, South Florida, Bermuda]
# 244   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 245   (6.0, 50.0)  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 250   (0.0, 12.0)                      [Bahamas, Caribbean, Florida]
# 265   (8.0, 23.0)                       [Eastern Caribbean, Bahamas]
# 270   (2.0, 23.0)             [Caribbean, Bahamas, Florida, Bermuda]
# 272   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 288   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 289   (3.0, 30.0)             [Bahamas, Caribbean, Florida, Bermuda]
#
#     smithsonian_href
# 2                NaN
# 7                NaN
# 29               NaN
# 41               NaN
# 46               NaN
# 65               NaN
# 69               NaN
# 72               NaN
# 78               NaN
# 82               NaN
# 84               NaN
# 100              NaN
# 101              NaN
# 106              NaN
# 115              NaN
# 137              NaN
# 142              NaN
# 153              NaN
# 155              NaN
# 158              NaN
# 161              NaN
# 198              NaN
# 199              NaN
# 214              NaN
# 215              NaN
# 216              NaN
# 221              NaN
# 225              NaN
# 230              NaN
# 235              NaN
# 244              NaN
# 245              NaN
# 250              NaN
# 265              NaN
# 270              NaN
# 272              NaN
# 288              NaN
# 289              NaN

# %%
reefguide_fish_DF['smithsonian_href'] = pd.Series(dtype = 'object')
for row in reefguide_fish_DF.iterrows():
    for entry in all_entries:
        
        if entry.get_text() in smith_interpreter.values():
            key_list = list(smith_interpreter.keys())
            val_list = list(smith_interpreter.values())
            pos = val_list.index(entry.get_text())
            smith_name = key_list[pos]

            for entry in all_entries:
                if smith_name in entry:
                    entry = entry
                    break

        if row[1].scientific_name == entry.get_text():
            row[1].smithsonian_href = entry.get('href')
            continue

# %%
reefguide_fish_DF.loc[reefguide_fish_DF.smithsonian_href.isna() ]
# Out:
#                scientific_name scientific_family  \
# 2              Manta birostris      Myliobatidae
# 7           Trichechus manatus      Trichechidae
# 29      Eretmochelys imbricata       Cheloniidae
# 41       Micrognathus crinitus      Syngnathidae
# 46     Isostichopus badionotus     Stichopodidae
# 72             Caretta caretta       Cheloniidae
# 84          Tursiops truncatus       Delphinidae
# 100        Holothuria mexicana     Holothuriidae
# 101       Narcine brasiliensis      Torpedinidae
# 106          Ectyoplasia ferox      Raspailiidae
# 158       Holothuria floridana     Holothuriidae
# 198             Chelonia mydas       Cheloniidae
# 199      Stenella longirostris       Delphinidae
# 214  Amphelikturus dendriticus      Syngnathidae
# 215             Ulaema lefroyi         Gerreidae
# 216        Himantura schmardae        Dasyatidae
# 221         Dasyatis americana        Dasyatidae
# 225         Holothuria thomasi     Holothuriidae
# 230    Emblemariopsis signifer      Chaenopsidae
# 235         Pseudothyone belli  Sclerodactylidae
# 244           Octopus macropus       Octopodidae
# 245        Paranthias furcifer        Serranidae
# 265       Eostichopus arnesoni     Stichopodidae
# 270      Sargocentron coruscum     Holocentridae
# 272           Octopus vulgaris       Octopodidae
# 288           Octopus briareus       Octopodidae
#
#                          common_name       common_family   size_range_cm  \
# 2                    Giant Manta Ray          Manta Rays  (180.0, 700.0)
# 7                West Indian Manatee            Manatees    (0.0, 400.0)
# 29                  Hawksbill Turtle             Turtles   (30.0, 107.0)
# 41                Harlequin Pipefish          Pipefishes    (12.0, 20.0)
# 46          Three-Rowed Sea Cucumber       Sea Cucumbers    (25.0, 40.0)
# 72                 Loggerhead Turtle             Turtles   (30.0, 100.0)
# 84                Bottlenose Dolphin            Dolphins  (152.0, 366.0)
# 100         Donkey Dung Sea Cucumber       Sea Cucumbers    (25.0, 35.0)
# 101              Lesser Electric Ray       Electric Rays    (25.0, 45.0)
# 106  Brown Encrusting Octopus Sponge      Common Sponges    (15.0, 40.0)
# 158             Florida Sea Cucumber       Sea Cucumbers     (7.0, 20.0)
# 198                     Green Turtle             Turtles   (30.0, 120.0)
# 199                  Spinner Dolphin            Dolphins    (0.0, 210.0)
# 214                        Pipehorse          Pipefishes      (0.0, 5.0)
# 215                  Mottled Mojarra            Mojarras     (0.0, 17.0)
# 216      Caribbean Whiptail Stingray  Whiptail Stingrays   (60.0, 120.0)
# 221                Southern Stingray  Whiptail Stingrays   (90.0, 150.0)
# 225          Tiger Tail Sea Cucumber       Sea Cucumbers   (90.0, 180.0)
# 230                   Flagfin Blenny       Tube Blennies      (0.0, 2.5)
# 235              Hidden Sea Cucumber       Sea Cucumbers      (1.2, 3.5)
# 244   Atlantic White-Spotted Octopus           Octopuses     (0.0, 50.0)
# 245              Atlantic Creolefish            Groupers    (10.0, 20.0)
# 265             Conical Sea Cucumber       Sea Cucumbers     (0.0, 40.0)
# 270                Reef Squirrelfish      Squirrelfishes     (8.0, 12.0)
# 272                   Common Octopus           Octopuses    (30.0, 90.0)
# 288           Caribbean Reef Octopus           Octopuses    (30.0, 60.0)
#
#     depth_range_m                                            geodist  \
# 2     (0.0, 12.0)                                   [Circumtropical]
# 7      (0.0, 3.0)                       [Florida, Caribbean, Brazil]
# 29    (0.0, 21.0)                                   [Circumtropical]
# 41    (2.0, 18.0)        [Caribbean, Bahamas, South Florida, Brazil]
# 46    (0.0, 60.0)             [Caribbean, Bahamas, Florida, Bermuda]
# 72    (0.0, 60.0)                                   [Circumtropical]
# 84         (0, 0)                [Warm and temperate seas worldwide]
# 100   (0.0, 37.0)                 [Caribbean, Bahamas, Florida Keys]
# 101   (0.0, 25.0)  [Florida, Gulf of Mexico, Southern Caribbean, ...
# 106   (6.0, 25.0)                      [Caribbean, Bahamas, Florida]
# 158    (1.0, 5.0)                      [Caribbean, Bahamas, Florida]
# 198   (0.0, 40.0)                                   [Circumtropical]
# 199        (0, 0)                                   [Circumtropical]
# 214   (1.0, 10.0)  [South Florida, Bahamas, Caribbean, Gulf of Me...
# 215    (0.0, 6.0)  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 216    (0.0, 6.0)                              [Northwest Caribbean]
# 221   (0.0, 25.0)      [Caribbean, Bahamas, Florida, Gulf of Mexico]
# 225   (3.0, 30.0)                      [Caribbean, Bahamas, Florida]
# 230   (8.0, 30.0)                               [Bahamas, Caribbean]
# 235   (0.0, 37.0)       [Caribbean, Bahamas, South Florida, Bermuda]
# 244   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 245   (6.0, 50.0)  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...
# 265   (8.0, 23.0)                       [Eastern Caribbean, Bahamas]
# 270   (2.0, 23.0)             [Caribbean, Bahamas, Florida, Bermuda]
# 272   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
# 288   (5.0, 23.0)                      [Caribbean, Bahamas, Florida]
#
#     smithsonian_href
# 2                NaN
# 7                NaN
# 29               NaN
# 41               NaN
# 46               NaN
# 72               NaN
# 84               NaN
# 100              NaN
# 101              NaN
# 106              NaN
# 158              NaN
# 198              NaN
# 199              NaN
# 214              NaN
# 215              NaN
# 216              NaN
# 221              NaN
# 225              NaN
# 230              NaN
# 235              NaN
# 244              NaN
# 245              NaN
# 265              NaN
# 270              NaN
# 272              NaN
# 288              NaN

# %%
reefguide_fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 289
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    289 non-null    object
#  1   scientific_family  289 non-null    object
#  2   common_name        289 non-null    object
#  3   common_family      289 non-null    object
#  4   size_range_cm      289 non-null    object
#  5   depth_range_m      289 non-null    object
#  6   geodist            289 non-null    object
#  7   smithsonian_href   263 non-null    object
# dtypes: object(8)
# memory usage: 20.3+ KB

# %% [markdown]
# Nice! seems good.... so let's drop the remaining rows containing NaNs and then pickle the new reefguide_fish_DF as well as save changes we made to both.

# %%
reefguide_fish_DF_1b = reefguide_fish_DF.copy()
reefguide_fish_DF_1b = reefguide_fish_DF_1b.reset_index(drop = True)
reefguide_fish_DF_2 = reefguide_fish_DF_1b.dropna()
reefguide_fish_DF_2 = reefguide_fish_DF_2.reset_index(drop = True)

# %%
reefguide_fish_DF_1b.to_pickle('./files/fishspecies_reefguide_info_1b.pkl')
reefguide_fish_DF_2.to_pickle('./files/fishspecies_reefguide_info_2.pkl')

# %%
fish_DF = pd.read_pickle('./files/fishspecies_reefguide_info_2.pkl')

# %%
fish_DF.head()
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 1   Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2        Apogon binotatus        Apogonidae  Barred Cardinalfish
# 3       Lutjanus mahogoni        Lutjanidae     Mahogany Snapper
# 4       Lutjanus synagris        Lutjanidae         Lane Snapper
#
#     common_family size_range_cm depth_range_m  \
# 0         Wrasses  (12.0, 20.0)   (2.0, 12.0)
# 1      Soapfishes   (7.5, 13.0)   (3.0, 21.0)
# 2  Cardinalfishes   (0.0, 10.0)   (1.0, 45.0)
# 3        Snappers  (18.0, 30.0)   (6.0, 18.0)
# 4        Snappers  (20.0, 30.0)   (2.0, 40.0)
#
#                                              geodist smithsonian_href
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...         spe/3894
# 1        [Caribbean, Bahamas, South Florida, Brazil]         spe/3537
# 2                [Caribbean, Bahamas, South Florida]         spe/3595
# 3      [Caribbean, Bahamas, Florida, Gulf of Mexico]         spe/3690
# 4  [Caribbean, Bahamas, Florida, Gulf of Mexico, ...         spe/3692

# %%
fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    263 non-null    object
#  1   scientific_family  263 non-null    object
#  2   common_name        263 non-null    object
#  3   common_family      263 non-null    object
#  4   size_range_cm      263 non-null    object
#  5   depth_range_m      263 non-null    object
#  6   geodist            263 non-null    object
#  7   smithsonian_href   263 non-null    object
# dtypes: object(8)
# memory usage: 16.6+ KB

# %% [markdown]
# Awesome! Now we have this to scrape images from, of course remembering to rename any of the folder structure from our initial reefguide scrape as necessary.

# %%
fish_DF.loc[fish_DF.scientific_name == 'Ginglymostoma cirratum']['smithsonian_href'].values[0].split('/')[-1]
# Out:
# '24'

# %% [markdown]
# Looking at the gallery pages for smithsonian, for some reason the href we found isn't what is used as the URL prefix. However, the number is correct as an ID so we can use that and append it to a standard URL.

# %%
nurse_gallery_URL = 'https://biogeodb.stri.si.edu/caribbean/en/gallery/specie/24'
page = requests.get(nurse_gallery_URL)
nurse_soup = BeautifulSoup(page.content, "html.parser")

# %%
blue_box = nurse_soup.find('div',{'class':'bg-blue'})
blue_box.find_all('img')[0].get('src')
# Out:
# '/caribbean/resources/img/images/species/24_247.jpg'

# %%
img_link = 'https://biogeodb.stri.si.edu/caribbean/resources/img/images/species/24_247.jpg'
img_data = requests.get(img_link).content
with open('nurse_test.jpg', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# Okay.. so while there are some restrictions due to copyright on this site, preventing downloading via right clicking, it seems that I can still scrape the images just fine sooooo let's go!

# %%
def smith_scrape(scientific_name,scientific_family,smithsonian_href,download_flag):
    ### This function takes in the end of a URL and uses it to access the appropriate webpage on reefguide.org
    ### For example, being passed 'flatneedle.html' will access the URL 'https://reefguide.org/carib/flatneedle.html'
    ### It will then collect the desired species information from the web page as well as download all the images
    ### If the download flag is boolean True using the function reefguide_images and store them in the appropriate folder
    ### on my HDD.

    # Get species N from href

    species_N = smithsonian_href.split('/')[-1]

    # Get page HTML

    smith_prefix = 'https://biogeodb.stri.si.edu/caribbean/en/gallery/specie/'
    species_URL = smith_prefix + species_N
    species_page = requests.get(species_URL)
    species_soup = BeautifulSoup(species_page.content, "html.parser")
    
    # Get Img Links

    blue_box = species_soup.find('div',{'class':'bg-blue'})
    img_link_suffixes = blue_box.find_all('img')

    if download_flag:
        smith_download(img_link_suffixes, scientific_family, scientific_name)
    else:
        pass

    return

def smith_download(img_link_suffixes,scientific_family,scientific_name):
    ### This function downloads all images from the species page and stores them in a species labelled folder on my HDD
    ### The folder is named for the scientific name as well as fits into the scientific family heirarchy
    ### The function will separate images into different folders based on labels such as juvenile, initial

    smith_pix_prefix = 'https://biogeodb.stri.si.edu'

    for html_suffix in img_link_suffixes:

        # Get Image URL and image data

        suffix = html_suffix.get('src')
        img_link = smith_pix_prefix + suffix
        img_data = requests.get(img_link).content

        # Construct save path (for some reason there are spaces at the end of the folders after the reefguide scrape?)

        path_prefix = 'E:/LargeDatasets/SpeciesID-Images/'
        folder_path = path_prefix + scientific_family + '/' + scientific_name.replace(' ','_') + '_'
        filename = suffix.split('/')[-1]
        img_path = folder_path + '/' + filename

        # check if path exists and if not make it so

        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # check if file already exists and if so skip

        if os.path.exists(img_path):
            continue
        
        with open(img_path, 'wb') as handler:
            handler.write(img_data)

    return

# %%
fish_DF.loc[fish_DF.scientific_name == 'Ginglymostoma cirratum']
# Out:
#             scientific_name   scientific_family  common_name common_family  \
# 158  Ginglymostoma cirratum  Ginglymostomatidae  Nurse Shark  Nurse Sharks
#
#       size_range_cm depth_range_m  \
# 158  (150.0, 350.0)   (4.0, 30.0)
#
#                                                geodist smithsonian_href
# 158  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...           spe/24

# %%
smith_scrape('Ginglymostoma cirratum','Ginglymostomatidae','spe/24',1)
# Out:
# 'works'

# %%
base_dir = 'E:/LargeDatasets/SpeciesID-Images/'
os.listdir(base_dir)
# Out:
# ['Acanthuridae',
#  'Albulidae',
#  'Apogonidae',
#  'Aulostomidae',
#  'Balistidae',
#  'Batrachoididae',
#  'Belonidae',
#  'Blenniidae',
#  'Bothidae',
#  'Callionymidae',
#  'Carangidae',
#  'Carcharhinidae',
#  'Chaenopsidae',
#  'Chaetodontidae',
#  'Cheloniidae',
#  'Cirrhitidae',
#  'Congridae',
#  'Cynoglossidae',
#  'Dactylopteridae',
#  'Dasyatidae',
#  'Delphinidae',
#  'Diodontidae',
#  'Echeneidae',
#  'Ephippidae',
#  'Fistulariidae',
#  'Gerreidae',
#  'Ginglymostomatidae',
#  'Gobiidae',
#  'Grammatidae',
#  'Haemulidae',
#  'Hemiramphidae',
#  'Holocentridae',
#  'Holothuriidae',
#  'Inermiidae',
#  'Kyphosinae',
#  'Labridae',
#  'Labrisomidae',
#  'Lutjanidae',
#  'Malacanthidae',
#  'Megalopidae',
#  'Monacanthidae',
#  'Mullidae',
#  'Muraenidae',
#  'Myliobatidae',
#  'Octopodidae',
#  'Ogcocephalidae',
#  'Ophichthidae',
#  'Opisthognathidae',
#  'Ostraciidae',
#  'Paralichthyidae',
#  'Pempheridae',
#  'Pomacanthidae',
#  'Pomacentridae',
#  'Priacanthidae',
#  'Raspailiidae',
#  'Rhincodontidae',
#  'Scaridae',
#  'Sciaenidae',
#  'Sclerodactylidae',
#  'Scombridae',
#  'Scorpaenidae',
#  'Serranidae',
#  'Sparidae',
#  'Sphyraenidae',
#  'Stichopodidae',
#  'Syngnathidae',
#  'Synodontidae',
#  'Tetraodontidae',
#  'Torpedinidae',
#  'Trichechidae',
#  'Tripterygiidae',
#  'Urotrygonidae']

# %%
os.listdir(base_dir+'Acanthuridae')
# Out:
# ['Acanthurus_chirurgus_',
#  'Acanthurus_coeruleus_',
#  'Acanthurus_coeruleus_Intermediate_Phase\xa0',
#  'Acanthurus_coeruleus_Juvenile\xa0',
#  'Acanthurus_tractus_Post-Larval_phase\xa0',
#  'Acanthurus_tractus_\xa0']

# %%
os.rename('E:/LargeDatasets/SpeciesID-Images/'+'Acanthuridae'+'/'+'Acanthurus_tractus_\xa0','E:/LargeDatasets/SpeciesID-Images/'+'Acanthuridae'+'/'+'Acanthurus_tractus_\xa0'.replace('\xa0',''))

# %%
base_dir = 'E:/LargeDatasets/SpeciesID-Images/'
family_dir = os.listdir(base_dir)

for family in family_dir:
    species_dir = os.listdir(base_dir+family)

    for species in species_dir:
        if '\xa0' in species:
            os.rename(base_dir+family+'/'+species,base_dir+family+'/'+species.replace('\xa0',''))

# %% [markdown]
# Okay, so there was an error somehow when I first scraped reefguide, likely due to how i handled 'phase_tag' that made it so there was a trailing whitespace on all my folder names. The above seems to have fixed that issue and was verified with the nurse shark download. Let's try the smith_scrape for all the species!

# %%
fish_DF.loc[fish_DF.scientific_name == 'Ginglymostoma cirratum'].apply(lambda x: smith_scrape(x.scientific_name, x.scientific_family, x.smithsonian_href,1), axis = 1)
# Out:
# 158    works
# dtype: object

# %%
fish_DF.loc[1:2]
# Out:
#          scientific_name scientific_family          common_name  \
# 1  Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2       Apogon binotatus        Apogonidae  Barred Cardinalfish
#
#     common_family size_range_cm depth_range_m  \
# 1      Soapfishes   (7.5, 13.0)   (3.0, 21.0)
# 2  Cardinalfishes   (0.0, 10.0)   (1.0, 45.0)
#
#                                        geodist smithsonian_href
# 1  [Caribbean, Bahamas, South Florida, Brazil]         spe/3537
# 2          [Caribbean, Bahamas, South Florida]         spe/3595

# %%
fish_DF.loc[1:2].apply(lambda x: smith_scrape(x.scientific_name, x.scientific_family, x.smithsonian_href,1), axis = 1)
# Out:
# 1    works
# 2    works
# dtype: object

# %%
fish_DF.apply(lambda x: smith_scrape(x.scientific_name, x.scientific_family, x.smithsonian_href,1), axis = 1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 258    None
# 259    None
# 260    None
# 261    None
# 262    None
# Length: 263, dtype: object

# %% [markdown]
# Hell yes!!!!! Looking through my images and seeing the new pictures all in the right folder is pretty bad ass. It really has improved the training set so far. Onto the next site!

# %% [markdown]
# ## Snorkel STJ

# %% [markdown]
# As with Smithsonian, we need to figure out how to look up the fish we already have in our DF on this website. They are by local common name, which may prove a challenge, but we will try our best.

# %%
URL = 'https://www.snorkelstj.com/list-species.html'
page = requests.get(URL)

STJ_soup = BeautifulSoup(page.content, "html.parser")

# %%
fish_DF = pd.read_pickle('./files/fishspecies_reefguide_info_2.pkl')

# %%
fish_DF.head()
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 1   Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2        Apogon binotatus        Apogonidae  Barred Cardinalfish
# 3       Lutjanus mahogoni        Lutjanidae     Mahogany Snapper
# 4       Lutjanus synagris        Lutjanidae         Lane Snapper
#
#     common_family size_range_cm depth_range_m  \
# 0         Wrasses  (12.0, 20.0)   (2.0, 12.0)
# 1      Soapfishes   (7.5, 13.0)   (3.0, 21.0)
# 2  Cardinalfishes   (0.0, 10.0)   (1.0, 45.0)
# 3        Snappers  (18.0, 30.0)   (6.0, 18.0)
# 4        Snappers  (20.0, 30.0)   (2.0, 40.0)
#
#                                              geodist smithsonian_href
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...         spe/3894
# 1        [Caribbean, Bahamas, South Florida, Brazil]         spe/3537
# 2                [Caribbean, Bahamas, South Florida]         spe/3595
# 3      [Caribbean, Bahamas, Florida, Gulf of Mexico]         spe/3690
# 4  [Caribbean, Bahamas, Florida, Gulf of Mexico, ...         spe/3692

# %%
fish_DF.common_family.value_counts()
# Out:
# Gobies                 23
# Wrasses                15
# Grunts                 12
# Parrotfishes           11
# Jacks                   9
#                        ..
# Cornetfishes            1
# Sweepers                1
# Mackerels and Tunas     1
# Round Stingrays         1
# Bonnetmouths            1
# Name: common_family, Length: 68, dtype: int64

# %% [markdown]
# Okay so the way that SnorkelSTJ is set up is that the page above has a list of species by common name. Once you go to a species page by clicking a common name, there is a header with the scientific name. So, what I think we are going to try first is to find all the common family divisions they have in the species list page, and cross reference that with our common family column. If there is acceptable overlap, we will get the HTML references from those family headers, then double check the scientific names when we actually access the pages themselves.

# %%
STJ_soup.find_all('span',{'class':'auto-style3'})
# Out:
# [<span class="auto-style3">snorkelstj.com</span>,
#  <span class="auto-style3">FISH </span>,
#  <span class="auto-style3">Angelfish</span>,
#  <span class="auto-style3">Barracuda:</span>,
#  <span class="auto-style3">Basslet:</span>,
#  <span class="auto-style3">Batfish:</span>,
#  <span class="auto-style3"> Blennies:</span>,
#  <span class="auto-style3"><a href="bonefish.html">Bonefish</a></span>,
#  <span class="auto-style3">Boxfish:</span>,
#  <span class="auto-style3">Butterflyfish:</span>,
#  <span class="auto-style3">Cardinal Fishes:</span>,
#  <span class="auto-style3">Chub:</span>,
#  <span class="auto-style3">Clingfish:</span>,
#  <span class="auto-style3">Damselfish:</span>,
#  <span class="auto-style3">Drums &amp; Croakers:</span>,
#  <span class="auto-style3">Eels:</span>,
#  <span class="auto-style3">Filefishes:</span>,
#  <span class="auto-style3">Flounder:</span>,
#  <span class="auto-style3">Goatfish:</span>,
#  <span class="auto-style3"><a href="goby_gallery.html">Gobies:</a></span>,
#  <span class="auto-style3">Groupers &amp; Sea Basses:</span>,
#  <span class="auto-style3">Flying Gurnards:</span>,
#  <span class="auto-style3">Grunts:</span>,
#  <span class="auto-style3"><a href="hamlets.html">Hamlets</a>:</span>,
#  <span class="auto-style3">Herring:</span>,
#  <span class="auto-style3">Jacks:</span>,
#  <span class="auto-style3"> Jawfish:</span>,
#  <span class="auto-style3">Lionfish:</span>,
#  <span class="auto-style3">Lizardfish:</span>,
#  <span class="auto-style3">Mackerel:</span>,
#  <span class="auto-style3">Margates:</span>,
#  <span class="auto-style3">Mojarra:</span>,
#  <span class="auto-style3">Mullets:</span>,
#  <span class="auto-style3">Needlefish:</span>,
#  <span class="auto-style3">Halfbeaks:</span>,
#  <span class="auto-style3">Parrotfishes:</span>,
#  <span class="auto-style3">Pipefish:</span>,
#  <span class="auto-style3">Porcupinefishes:</span>,
#  <span class="auto-style3">Porgies:</span>,
#  <span class="auto-style3">Pufferfishes:</span>,
#  <span class="auto-style3">Rays:</span>,
#  <span class="auto-style3">Remoras:</span>,
#  <span class="auto-style3">Scorpionfish:</span>,
#  <span class="auto-style3">Sea Horses:</span>,
#  <span class="auto-style3">Sharks:</span>,
#  <span class="auto-style3">Snappers:</span>,
#  <span class="auto-style3">Snook:</span>,
#  <span class="auto-style3">Squirrelfishes:</span>,
#  <span class="auto-style3">Stingray:</span>,
#  <span class="auto-style3">Surgeonfish:</span>,
#  <span class="auto-style3">Sweepers:</span>,
#  <span class="auto-style3">Tarpon</span>,
#  <span class="auto-style3">Triggerfish:</span>,
#  <span class="auto-style3">Tilefish:</span>,
#  <span class="auto-style3"><a href="trumpetfish.html"> Trumpetfish</a></span>,
#  <span class="auto-style3">Trunkfish:</span>,
#  <span class="auto-style3">Wrasses:</span>,
#  <span class="auto-style3">Creatures</span>,
#  <span class="auto-style3">Sea Anemones:</span>,
#  <span class="auto-style3"><a href="crustaceans_gallery.html">Barnacles:</a></span>,
#  <span class="auto-style3">Bivalves:</span>,
#  <span class="auto-style3">Bryozoans:</span>,
#  <span class="auto-style3">Chitons:</span>,
#  <span class="auto-style3">Comb Jellies </span>,
#  <span class="auto-style3">Corallomorph:</span>,
#  <span class="auto-style3">Crabs:</span>,
#  <span class="auto-style3">Hydroids:</span>,
#  <span class="auto-style3"><a href="isopod.html">Isopod:</a></span>,
#  <span class="auto-style3">Jellyfish:</span>,
#  <span class="auto-style3">Lobster: </span>,
#  <span class="auto-style3">Limpets:</span>,
#  <span class="auto-style3">Nudibranch:</span>,
#  <span class="auto-style3">Oysters:See bivalves<br/>
#  Octopus:</span>,
#  <span class="auto-style3">Sea Cucumbers:</span>,
#  <span class="auto-style3">Sea Slugs:</span>,
#  <span class="auto-style3">Seahares:</span>,
#  <span class="auto-style3">Shrimp:</span>,
#  <span class="auto-style3">Snails:</span>,
#  <span class="auto-style3">Sponges:</span>,
#  <span class="auto-style3">Squid:</span>,
#  <span class="auto-style3">Starfish:</span>,
#  <span class="auto-style3">Sea Stars:</span>,
#  <span class="auto-style3">Tunicates:</span>,
#  <span class="auto-style3">Urchins:</span>,
#  <span class="auto-style3">Worms:</span>,
#  <span class="auto-style3">Zoanthids:</span>,
#  <span class="auto-style3">CORALS</span>,
#  <span class="auto-style3">Fire Corals:</span>,
#  <span class="auto-style3">Stony Corals:</span>,
#  <span class="auto-style3">Octocorals:</span>,
#  <span class="auto-style3"><a href="plants-algae_gallery.html">Plants and Algae, Bacteria and Lichens</a></span>,
#  <span class="auto-style3"><a href="diseases.html">Diseases:</a></span>,
#  <span class="auto-style3"><a href="bacteria-lichens.html">Cyanobacteria and Lichens </a> </span>]

# %%
family_headers = STJ_soup.find_all('span',{'class':'auto-style3'})
text_list = []
for family in family_headers:
    text_list.append(family.get_text())

# %%
text_list = [text.strip().strip(':') for text in text_list]

# %%
text_list
# Out:
# ['snorkelstj.com',
#  'FISH',
#  'Angelfish',
#  'Barracuda',
#  'Basslet',
#  'Batfish',
#  'Blennies',
#  'Bonefish',
#  'Boxfish',
#  'Butterflyfish',
#  'Cardinal Fishes',
#  'Chub',
#  'Clingfish',
#  'Damselfish',
#  'Drums & Croakers',
#  'Eels',
#  'Filefishes',
#  'Flounder',
#  'Goatfish',
#  'Gobies',
#  'Groupers & Sea Basses',
#  'Flying Gurnards',
#  'Grunts',
#  'Hamlets',
#  'Herring',
#  'Jacks',
#  'Jawfish',
#  'Lionfish',
#  'Lizardfish',
#  'Mackerel',
#  'Margates',
#  'Mojarra',
#  'Mullets',
#  'Needlefish',
#  'Halfbeaks',
#  'Parrotfishes',
#  'Pipefish',
#  'Porcupinefishes',
#  'Porgies',
#  'Pufferfishes',
#  'Rays',
#  'Remoras',
#  'Scorpionfish',
#  'Sea Horses',
#  'Sharks',
#  'Snappers',
#  'Snook',
#  'Squirrelfishes',
#  'Stingray',
#  'Surgeonfish',
#  'Sweepers',
#  'Tarpon',
#  'Triggerfish',
#  'Tilefish',
#  'Trumpetfish',
#  'Trunkfish',
#  'Wrasses',
#  'Creatures',
#  'Sea Anemones',
#  'Barnacles',
#  'Bivalves',
#  'Bryozoans',
#  'Chitons',
#  'Comb Jellies',
#  'Corallomorph',
#  'Crabs',
#  'Hydroids',
#  'Isopod',
#  'Jellyfish',
#  'Lobster',
#  'Limpets',
#  'Nudibranch',
#  'Oysters:See bivalves\nOctopus',
#  'Sea Cucumbers',
#  'Sea Slugs',
#  'Seahares',
#  'Shrimp',
#  'Snails',
#  'Sponges',
#  'Squid',
#  'Starfish',
#  'Sea Stars',
#  'Tunicates',
#  'Urchins',
#  'Worms',
#  'Zoanthids',
#  'CORALS',
#  'Fire Corals',
#  'Stony Corals',
#  'Octocorals',
#  'Plants and Algae, Bacteria and Lichens',
#  'Diseases',
#  'Cyanobacteria and Lichens']

# %%
overlap = [ text for text in text_list if text in fish_DF.common_family.values ]
not_in = [ text for text in text_list if text not in fish_DF.common_family.values ]

# %%
overlap
# Out:
# ['Filefishes',
#  'Gobies',
#  'Flying Gurnards',
#  'Grunts',
#  'Hamlets',
#  'Jacks',
#  'Halfbeaks',
#  'Parrotfishes',
#  'Porcupinefishes',
#  'Porgies',
#  'Pufferfishes',
#  'Remoras',
#  'Snappers',
#  'Squirrelfishes',
#  'Sweepers',
#  'Wrasses']

# %%
not_in
# Out:
# ['snorkelstj.com',
#  'FISH',
#  'Angelfish',
#  'Barracuda',
#  'Basslet',
#  'Batfish',
#  'Blennies',
#  'Bonefish',
#  'Boxfish',
#  'Butterflyfish',
#  'Cardinal Fishes',
#  'Chub',
#  'Clingfish',
#  'Damselfish',
#  'Drums & Croakers',
#  'Eels',
#  'Flounder',
#  'Goatfish',
#  'Groupers & Sea Basses',
#  'Herring',
#  'Jawfish',
#  'Lionfish',
#  'Lizardfish',
#  'Mackerel',
#  'Margates',
#  'Mojarra',
#  'Mullets',
#  'Needlefish',
#  'Pipefish',
#  'Rays',
#  'Scorpionfish',
#  'Sea Horses',
#  'Sharks',
#  'Snook',
#  'Stingray',
#  'Surgeonfish',
#  'Tarpon',
#  'Triggerfish',
#  'Tilefish',
#  'Trumpetfish',
#  'Trunkfish',
#  'Creatures',
#  'Sea Anemones',
#  'Barnacles',
#  'Bivalves',
#  'Bryozoans',
#  'Chitons',
#  'Comb Jellies',
#  'Corallomorph',
#  'Crabs',
#  'Hydroids',
#  'Isopod',
#  'Jellyfish',
#  'Lobster',
#  'Limpets',
#  'Nudibranch',
#  'Oysters:See bivalves\nOctopus',
#  'Sea Cucumbers',
#  'Sea Slugs',
#  'Seahares',
#  'Shrimp',
#  'Snails',
#  'Sponges',
#  'Squid',
#  'Starfish',
#  'Sea Stars',
#  'Tunicates',
#  'Urchins',
#  'Worms',
#  'Zoanthids',
#  'CORALS',
#  'Fire Corals',
#  'Stony Corals',
#  'Octocorals',
#  'Plants and Algae, Bacteria and Lichens',
#  'Diseases',
#  'Cyanobacteria and Lichens']

# %%
fish_DF.common_family.nunique()
# Out:
# 68

# %% [markdown]
# Hmm.. not great. Let's just manual up this bad boy

# %%
fish_DF.common_family.value_counts().index
# Out:
# Index(['Gobies', 'Wrasses', 'Grunts', 'Parrotfishes', 'Jacks', 'Seabasses',
#        'Groupers', 'Damselfishes', 'Hamlets', 'Snappers', 'Cardinalfishes',
#        'Moray Eels', 'Labrisomid Blennies', 'Angelfishes', 'Tube Blennies',
#        'Porcupinefishes', 'Porgies', 'Scorpionfishes', 'Butterflyfishes',
#        'Filefishes', 'Boxfishes', 'Squirrelfishes', 'Triggerfishes', 'Drums',
#        'Chromis', 'Snake Eels', 'Soapfishes', 'Chubs', 'Toadfishes',
#        'Surgeonfishes', 'Jawfishes', 'Requiem Sharks', 'Pufferfishes',
#        'Goatfishes', 'Combtooth Blennies', 'Needlefishes', 'Remoras',
#        'Lefteye Flounders', 'Bigeyes', 'Lizardfishes', 'Basslets', 'Seahorses',
#        'Spadefishes', 'Trumpetfishes', 'Flying Gurnards', 'Triplefin Blennies',
#        'Tonguefishes', 'Lionfishes', 'Soldierfishes', 'Dragonets', 'Halfbeaks',
#        'Mojarras', 'Barracudas', 'Tilefishes', 'Eagle Rays', 'Nurse Sharks',
#        'Bonefishes', 'Whale Sharks', 'Tarpons', 'Sand Flounders',
#        'Garden Eels', 'Hawkfishes', 'Batfishes', 'Cornetfishes', 'Sweepers',
#        'Mackerels and Tunas', 'Round Stingrays', 'Bonnetmouths'],
#       dtype='object')

# %%
manual_clean = [ 'Angelfish',
 'Barracuda',
 'Basslet',
 'Batfish',
 'Blennies',
 'Bonefish',
 'Boxfish',
 'Butterflyfish',
 'Cardinal Fishes',
 'Chub',
 'Clingfish',
 'Damselfish',
 'Drums & Croakers',
 'Eels',
 'Flounder',
 'Goatfish',
 'Groupers & Sea Basses',
 'Herring',
 'Jawfish',
 'Lionfish',
 'Lizardfish',
 'Mackerel',
 'Margates',
 'Mojarra',
 'Mullets',
 'Needlefish',
 'Pipefish',
 'Rays',
 'Scorpionfish',
 'Sea Horses',
 'Sharks',
 'Snook',
 'Stingray',
 'Surgeonfish',
 'Tarpon',
 'Triggerfish',
 'Tilefish',
 'Trumpetfish',
 'Trunkfish',
 'Creatures',
 'Sea Anemones',
 'Barnacles',
 'Bivalves',
 ]
desired_groups = list(set(overlap + manual_clean))

# %%
content = STJ_soup.find('section',{'id':'content'})

# %%
content.find('span').find_next('span')
# Out:
# <span class="auto-style3">Angelfish</span>

# %%
content.find('a')
# Out:
# <a href="french-angelfish.html">French</a>

# %%
content.find('li')
# Out:
# <li><a href="french-angelfish.html">French</a><br/>
# <a href="gray-angelfish.html">Gray</a><br/>
# <a href="queen-angelfish.html">Queen</a><br/>
# <a href="rock-beauty-angelfish.html">Rock Beauty </a></li>

# %%
href_list = []
for a_sect in content.find_all('a'):
    href_list.append(a_sect.get('href'))

# %%
href_list
# Out:
# ['french-angelfish.html',
#  'gray-angelfish.html',
#  'queen-angelfish.html',
#  'rock-beauty-angelfish.html',
#  'rock-beauty-angelfish.html',
#  'barracuda.html',
#  'fairy-basslet.html',
#  'harleguin-bass.html',
#  'shortnose-batfish.html',
#  'blenny_gallery.html',
#  'barfin-blenny.html',
#  'blennies.html',
#  'dusky-blenny.html',
#  'goldline-blenny.html',
#  'hairy-blenny.html',
#  'mimic-blenny.html',
#  'molly-miller.html',
#  'orangespotted-blenny.html',
#  'pearl-blenny.html',
#  'puffcheek-blenny.html',
#  'redlip-blenny.html',
#  'rosy-blenny.html',
#  'triplefin.html',
#  'saddled-blenny.html',
#  'seaweed-blenny.html',
#  'secretary-blenny.html',
#  'spinyhead-blenny.html',
#  'spotcheek-blenny.html',
#  'twinhorn-blenny.html',
#  'bonefish.html',
#  'honeycomb-cowfish.html',
#  'scrawled-cowfish.html',
#  'banded-butterflyfish.html',
#  '4eye-butterfly.html',
#  'spotfin-butterflyfish.html',
#  'belted-cardinalfish.html',
#  'blackfin-cardinalfish.html',
#  'flamefish.html',
#  'dusky-cardinalfish.html',
#  'chub.html',
#  'clingfish_gallery.html',
#  'beaugregory.html',
#  'bi-colored-damselfish.html',
#  'chromis.html',
#  'chromis.html',
#  'cocoa-damselfish.html',
#  'dusky-damselfish.html',
#  'longfin-damselfish.html',
#  'night-sergeant.html',
#  'threespot-damselfish.html',
#  'sergeant-major.html',
#  'yellowtail-damselfish.html',
#  'spotted-drum.html',
#  'highhat.html',
#  'reef-croaker.html',
#  'brown-garden-eel.html',
#  'chain-moray-eel.html',
#  'chestnut-moray.html',
#  'goldentail-moray.html',
#  'goldspotted-eel.html',
#  'green-moray-eel.html',
#  'purplemouth-moray.html',
#  'eels.html',
#  'spotted-moray-eel.html',
#  'orangespotted-filefish.html',
#  'scrawled-filefish.html',
#  'slender-filefish.html',
#  'whitespotted-filefish.html',
#  'unicorn-filefish.html',
#  'peacock-flounder.html',
#  'spotted-goatfish.html',
#  'yellow-goatfish.html',
#  'goby_gallery.html',
#  'cleaning-goby.html',
#  'colon-goby.html',
#  'dash-goby.html',
#  'frillfin-goby.html',
#  'masked-glass-goby.html',
#  'goldspot-goby.html',
#  'greenbanded-goby.html',
#  'masked-glass-goby.html',
#  'smallfish_gallery.html',
#  'smallfish_gallery.html',
#  'black-grouper.html',
#  'coney.html',
#  'graysby.html',
#  'greater-soapfish.html',
#  'mutton-hamlet.html',
#  'nassau-grouper.html',
#  'red-hind.html',
#  'rock-hind.html',
#  'tobaccofish.html',
#  'flying-gurnard.html',
#  'black-margate.html',
#  'bluestriped-grunt.html',
#  'caesar-grunt.html',
#  'french-grunt.html',
#  'porkfish.html',
#  'sailors-choice.html',
#  'smallmouth-grunt.html',
#  'spanish-grunt.html',
#  'tomtate-grunt.html',
#  'white-margate.html',
#  'white-grunt.html',
#  'hamlets.html',
#  'barred-hamlet.html',
#  'hybrid-black-hamlet.html',
#  'butter-hamlet.html',
#  'indigo-hamlet.html',
#  'mutton-hamlet.html',
#  'tan-hamlet.html',
#  'hybrid-yellowbelly-hamlet.html',
#  'yellowtail-hamlet.html',
#  'hybrid-yellowtail-hamlet.html',
#  'red-ear-herring.html',
#  'smallfish_gallery.html',
#  'almaco-jack.html',
#  'bar-jack.html',
#  'bigeye-scad.html',
#  'blue-runner-jack.html',
#  'horse-eye-jack.html',
#  'leather-jacket.html',
#  'palometa-jack.html',
#  'permit-jack.html',
#  'yellow-jack.html',
#  'jawfish.html',
#  'banded-jawfish.html',
#  'mottled-jawfish.html',
#  'yellowhead-jawfish.html',
#  'indo-pacific-lionfish.html',
#  'sand-diver-lizardfish.html',
#  'inshore-lizardfish.html',
#  'cero-mackerel.html',
#  'black-margate.html',
#  'white-margate.html',
#  'flagfin-mojarra.html',
#  'mottled-mojarra.html',
#  'yellowfin-mojarra.html',
#  'white-mullet.html',
#  'needlefish.html',
#  'needlefish.html',
#  'needlefish.html',
#  'ballyhoo.html',
#  'bucktooth-parrotfish.html',
#  'princess-parrotfish.html',
#  'queen-parrotfish.html',
#  'rainbow-parrotfish.html',
#  'redband-parrotfish.html',
#  'redfin-yellowtail-parrotfish.html',
#  'stoplight-parrotfish.html',
#  'striped-parrotfish.html',
#  'harlequin-pipefish.html',
#  'shortfin-pipefish.html',
#  'balloonfish.html',
#  'bridled-burrfish.html',
#  'porcupinefish.html',
#  'sea-bream.html',
#  'sheepshead-porgy.html',
#  'silver-porgy.html',
#  'bandtail-pufferfish.html',
#  'checkered-pufferfish.html',
#  'sharpnose-pufferfish.html',
#  'sharks-rays_.html',
#  'southern-stingray.html',
#  'spotted-eagle-ray.html',
#  'sharksucker.html',
#  'plumed-scorpionfish.html',
#  'reef-scorpionfish.html',
#  'spotted-scorpionfish.html',
#  'oddfish_gallery.html',
#  'blacktip-shark.html',
#  'sharks.html',
#  'lemon-shark.html',
#  'nurse-shark.html',
#  'cubera-snapper.html',
#  'dog-snapper.html',
#  'glasseye-snapper.html',
#  'gray-snapper.html',
#  'lane-snapper.html',
#  'mahogany-snapper.html',
#  'mutton-snapper.html',
#  'schoolmaster-snapper.html',
#  'yellowtail-snapper.html',
#  'common-snook.html',
#  'blackbar-soldierfish.html',
#  'common-squirrelfish.html',
#  'dusky-squirrelfish.html',
#  'longspine-squirrelfish.html',
#  'reef-squirrelfish.html',
#  'southern-stingray.html',
#  'blue-tang.html',
#  'doctorfish.html',
#  'surgeonfish.html',
#  'glassy-sweeper.html',
#  'tarpon.html',
#  'queen-triggerfish.html',
#  'oddfish_gallery.html',
#  'sand-tilefish.html',
#  'trumpetfish.html',
#  'buffalo-trunkfish.html',
#  'smooth-trunkfish.html',
#  'spotted-trunkfish.html',
#  'blackear-wrasse.html',
#  'bluehead-wrasse.html',
#  'clown-wrasse.html',
#  'creole-wrasse.html',
#  'green-razorfish.html',
#  'pearly-razorfish.html',
#  'puddingwife.html',
#  'rosy-razorfish.html',
#  'slippery-dick-wrasse.html',
#  'spanish-hogfish.html',
#  'yellowhead-wrasse.html',
#  'warty-sea-anemone.html',
#  'beaded-anemone.html',
#  'stinging-anemone.html',
#  'club-tip-hidden-anemone.html',
#  'corkscrew-anemone.html',
#  'elegant-anemone.html',
#  'giant-anemone.html',
#  'hidden-anemone.html',
#  'knobby-anemone.html',
#  'mangrove-sponge-anemone.html',
#  'pale-anemone.html',
#  'warty-sea-anemone.html',
#  'mangrove-sponge-anemone.html',
#  'sun-anemone.html',
#  'tube-dwelling-anemone.html',
#  'two-row-beaded-anemone.html',
#  'crustaceans_gallery.html',
#  'barnacles.html',
#  'barnacles.html',
#  'amber-penshell.html',
#  'atlantic-thorny-oyster.html',
#  'atlantic-wing-oyster.html',
#  'flat-tree-oyster.html',
#  'frond-oysters.html',
#  'purse-oyster.html',
#  'rough-fileclam.html',
#  'bryozoan_gallery.html',
#  'mollusks_gallery.html',
#  'chitons.html',
#  'chitons.html',
#  'chitons.html',
#  'chitons.html',
#  'chitons.html',
#  'cnidarians_gallery.html',
#  'comb-jelly.html',
#  'corallimorph.html',
#  'florida-false-coral.html',
#  'banded-clinging-crab.html',
#  'batwing-coral-crab.html',
#  'bareye-hermit-crab.html',
#  'blue-porcelain-crab.html',
#  'blue-crab.html',
#  'decorator-crab.html',
#  'flame-box-crab.html',
#  'gaudy-clown-crab.html',
#  'giant-hermit-crab.html',
#  'green-clinging-crab.html',
#  'clinging-crabs.html',
#  'king-crab.html',
#  'nimble-spray-crab.html',
#  'ocellate-swimming-crab.html',
#  'orange-claw-hermit-crab.html',
#  'clinging-crabs.html',
#  'red-ridge-clinging-crab.html',
#  'sally-lightfoot-crab.html',
#  'stareye-hermit-crab.html',
#  'tidal-spray-crab.html',
#  'tiny-red-crab.html',
#  'clinging-crabs.html',
#  'white-speckled-hermit-crab.html',
#  'yellowline-arrow-crab.html',
#  'unbranched-hydroid.html',
#  'branching-hydroid.html',
#  'christmas-tree-hydroid.html',
#  'white-stinger-hydroid.html',
#  'isopod.html',
#  'ctenophores_gallery.html',
#  'sea-wasp.html',
#  'club-hydromedusa.html',
#  'moon-jellyfish.html',
#  'mangrove-upsidedown-jellyfish.html',
#  'upsidedown-jellyfish.html',
#  'caribbean-spiny-lobster.html',
#  'spanish-slipper-lobster.html',
#  'spotted-spiny-lobster.html',
#  'limpet-snail.html',
#  'limpet-snail.html',
#  'limpet-snail.html',
#  'brown-doris.html',
#  'fringe-back-nudibranch.html',
#  'slimy-doris.html',
#  'White-Patch-Aeolid.html',
#  'common-octopus.html',
#  'caribbean-reef-octopus.html',
#  'two-spot-octopus.html',
#  'beaded-sea-cucumber.html',
#  'burrowing-sea-cucumber.html',
#  'donkey-dung-sea-cucumber.html',
#  'five-toothed-sea-cucumber.html',
#  'florida-sea-cucumber.html',
#  'furry-sea-cucumber.html',
#  'grub-sea-cucumber.html',
#  'hidden-sea-cucumber.html',
#  'slender-sea-cucumber.html',
#  'three-rowed-sea-cucumber.html',
#  'unknown-sea-cucumber.html',
#  'apricot-sidegill-slug.html',
#  'lettuce-sea-slug.html',
#  'mysterious-headshield-slug.html',
#  'reticulated-sea-slug.html',
#  'warty-sidegill-slug.html',
#  'ragged-seahare.html',
#  'spotted-seahare.html',
#  'warty-seacat.html',
#  'banded-coral-shrimp.html',
#  'brown-glass-shrimp.html',
#  'ciliated-false-squilla.html',
#  'commensal-urchin-shrimp.html',
#  'golden-coral-shrimp.html',
#  'mantis-shrimp.html',
#  'mysid-shrimp.html',
#  'pederson-cleaning-shrimp.html',
#  'crustaceans_gallery.html',
#  'prawn.html',
#  'red-night-shrimp.html',
#  'red-snapping-shrimp.html',
#  'spotted-cleaner-shrimp.html',
#  'sun-anemone-shrimp.html',
#  'swollen-claw-mantis-shrimp.html',
#  'unidentified-crustations.html',
#  'apple-murex.html',
#  'atlantic-tritons-trumpet.html',
#  'conch.html',
#  'fingerprint-cyphoma.html',
#  'flamingo-tongue.html',
#  'helmet-snail.html',
#  'limpet-snail.html',
#  'longspine-starsnail.html',
#  'milk-conch.html',
#  'miniature-melo-headshield-slug.html',
#  'mollusks_gallery.html',
#  'mollusks_gallery.html',
#  'mollusks_gallery.html',
#  'stocky-cerith.html',
#  'true-tulip-snail.html',
#  'west-indian-starsnail.html',
#  'west-indian-top-shell.html',
#  'wormsnail.html',
#  'black-ball-sponges.html',
#  'black-pinnacle-sponge.html',
#  'bowl-sponge.html',
#  'branching-tube-sponge.html',
#  'branching-vase-sponge.html',
#  'cake-sponge.html',
#  'convoluted-brain-sponge.html',
#  'coral-encrusting-sponge.html',
#  'other-sponges.html',
#  'elongated-vase-sponge.html',
#  'encrusting-sponge.html',
#  'fungus-sponge.html',
#  'giant-barrel-sponge.html',
#  'other-sponges.html',
#  'volcano-fire-sponge.html',
#  'other-sponges.html',
#  'heavenly-sponge.html',
#  'black-ball-sponges.html',
#  'lavender-rope-sponge.html',
#  'lobed-tube-sponge.html',
#  'green-mangrove-bulb-sponge.html',
#  'netted-barrel-sponge.html',
#  'octopus-sponge.html',
#  'orange-ball-sponge.html',
#  'orange-icing-sponge.html',
#  'orange-lumpy-encrusting-sponge.html',
#  'orange-perforated-sponge.html',
#  'orange-veined-encrusting-sponge.html',
#  'pink-and-red-encrusting-sponge.html',
#  'pink-encrusting-sponge.html',
#  'red-orange-encrusting-sponge.html',
#  'red-encrusting-sponge.html',
#  'red-sieve-encrusting-sponge.html',
#  'lumpy-overgrowing-sponges.html',
#  'pink-vase-sponge.html',
#  'pitted-tube-sponge.html',
#  'red-blister-sponge.html',
#  'red-boring-sponge.html',
#  'rippled-vase-sponge.html',
#  'row-pore-sponges.html',
#  'scattered-pore-sponges.html',
#  'star-encrusting-sponge.html',
#  'stinker-sponge.html',
#  'strawberry-sponge.html',
#  'touch-me-not-sponge.html',
#  'branching-tube-sponge.html',
#  'yellow-net-sponge.html',
#  'bowl-sponge.html',
#  'volcano-fire-sponge.html',
#  'caribbean-reef-squid.html',
#  'arrow-squid.html',
#  'brittle-star.html',
#  'short-spine-brittle-star.html',
#  'blunt-spine-brittle-stars.html',
#  'circle-marked-brittle-star.html',
#  'basket-star.html',
#  'blunt-spine-brittle-stars.html',
#  'long-spine-brittle-stars.html',
#  'short-spine-brittle-star.html',
#  'short-spine-brittle-star.html',
#  'reticulated-brittle-star.html',
#  'cushion-sea-star.html',
#  'cushion-sea-star.html',
#  'common-comet-star.html',
#  'black-tunicate.html',
#  'bleeding-heart-tunicate.html',
#  'blue-bell-tunicate.html',
#  'bulb-tunicate.html',
#  'button-tunicate.html',
#  'encrusting-social-tunicate.html',
#  'flat-tunicate.html',
#  'geometric-tunicate.html',
#  'giant-tunicate.html',
#  'green-encrusting-tunicate.html',
#  'green-tube-tunicate.html',
#  'mangrove-tunicate.html',
#  'mangrove-tunicate.html',
#  'mottled-tunicate.html',
#  'overgrowing-mat-tunicate.html',
#  'overgrowing-tunicate.html',
#  'painted-tunicate.html',
#  'tunicate_gallery.html',
#  'strawberry-tunicate.html',
#  'white-speck-tunicate.html',
#  'rock-boring-urchins.html',
#  'long-spined-urchin.html',
#  'magnificent-urchin.html',
#  'red-heart-urchin.html',
#  'reef-urchin.html',
#  'slate-pencil-sea-urchin.html',
#  'west-indian-sea-egg.html',
#  'variegated-sea-urchin.html',
#  'bearded-fireworm.html',
#  'black-spotted-tube-worm.html',
#  'worms_gallery.html',
#  'christmas-tree-worm.html',
#  'netted-flatworm.html',
#  'horseshoe-worm.html',
#  'magnificent-featherduster-worm.html',
#  'orange-fire-worm.html',
#  'punchbowl-tube-worm.html',
#  'polychaete-worm.html',
#  'red-colonial-tube-worm.html',
#  'social-feather-duster-worms.html',
#  'southern-lugworm%20.html',
#  'spaghetti-worm.html',
#  'split-crown-featherduster-worm.html',
#  'spoon-worm.html',
#  'star-horseshoe-worm.html',
#  'worms_gallery.html',
#  'variegated-feather-duster-worm.html',
#  'yellow-fanworm.html',
#  'cnidarians_gallery.html',
#  'mat-zoanthids.html',
#  'sponge-zoanthid.html',
#  'white-encrusting-zoanthid.html',
#  'hidden-cup-coral.html',
#  'orange-cup-coral.html',
#  'smooth-flower-coral.html',
#  'speckled-cup-coral.html',
#  'blade-fire-coral.html',
#  'hydrocorals_gallery.html',
#  'branching-fire-coral.html',
#  'blue-crust-coral.html',
#  'boulder-brain-coral.html',
#  'boulder-star-coral.html',
#  'finger-corals.html',
#  'corky-sea-finger.html',
#  'disk-corals.html',
#  'elkhorn-coral.html',
#  'elliptical-star-coral.html',
#  'encrusting-gorgonian.html',
#  'fused-staghorn-coral.html',
#  'giant-brain-coral.html',
#  'golfball-coral.html',
#  'great-star-coral.html',
#  'grooved-brain-coral.html',
#  'honeycomb-plate-coral.html',
#  'knobby-brain-coral.html',
#  'knobby-star-coral.html',
#  'lesser-starlet-coral.html',
#  'lettuce-coral.html',
#  'massive-starlet-coral.html',
#  'maze-coral.html',
#  'mustard-hill-coral.html',
#  'pillar-coral.html',
#  'plate-lettuce-coral.html',
#  'rose-coral.html',
#  'stony-corals_gallery.html',
#  'scaled-lettuce-coral.html',
#  'smooth-star-coral.html',
#  'staghorn-coral.html',
#  'symmetrical-brain-coral.html',
#  'ten-ray-star-coral.html',
#  'thin-leaf-lettuce-coral.html',
#  'tube-coral.html',
#  'yellow-pencil-coral.html',
#  'bent-sea-rod.html',
#  'black-sea-rod.html',
#  'common-sea-fan.html',
#  'corky-sea-finger.html',
#  'corky-sea-finger.html',
#  'doughnut-sea-rod.html',
#  'elliptical-star-coral.html',
#  'encrusting-gorgonian.html',
#  'knobby-sea-rods.html',
#  'porous-sea-rods.html',
#  'sea-plumes.html',
#  'shelf-knob-sea-rod.html',
#  'spiny-sea-fan.html',
#  'split-pore-sea-rod.html',
#  'venus-sea-fan.html',
#  'white-telesto.html',
#  'wide-mesh-sea-fan.html',
#  'yellow-sea-whip.html',
#  'plants-algae_gallery.html',
#  None,
#  None,
#  None,
#  'plants-algae_gallery.html',
#  'plants-algae_gallery.html',
#  'burgundy-crust-alga.html',
#  'coralline-algae.html',
#  'dead-mans-fingers.html',
#  'elongated-sea-pearl.html',
#  'plants-algae_gallery.html',
#  'mermaids-fan.html',
#  'plants-algae_gallery.html',
#  'plants-algae_gallery.html',
#  'crustose-coralline-algae.html',
#  'plants-algae_gallery.html',
#  'sea-pearl.html',
#  'spiny-seaweed.html',
#  'plants-algae_gallery.html',
#  'diseases.html',
#  'diseases.html',
#  'diseases.html',
#  'bacteria-lichens.html']

# %% [markdown]
# Sigh... looks like we will just clean the html list manually. The page structure is not well organized / consistent so trying to extract only the appropriate hrefs is getting annoying. Since I will need to perform a check on the scientific name once entering the species page, no need to do an extensive check here.

# %%
STJ_hrefs = ['french-angelfish.html',
 'gray-angelfish.html',
 'queen-angelfish.html',
 'rock-beauty-angelfish.html',
 'barracuda.html',
 'fairy-basslet.html',
 'harleguin-bass.html',
 'shortnose-batfish.html',
 'barfin-blenny.html',
 'dusky-blenny.html',
 'goldline-blenny.html',
 'hairy-blenny.html',
 'mimic-blenny.html',
 'molly-miller.html',
 'orangespotted-blenny.html',
 'pearl-blenny.html',
 'puffcheek-blenny.html',
 'redlip-blenny.html',
 'rosy-blenny.html',
 'triplefin.html',
 'saddled-blenny.html',
 'seaweed-blenny.html',
 'secretary-blenny.html',
 'spinyhead-blenny.html',
 'spotcheek-blenny.html',
 'twinhorn-blenny.html',
 'bonefish.html',
 'honeycomb-cowfish.html',
 'scrawled-cowfish.html',
 'banded-butterflyfish.html',
 '4eye-butterfly.html',
 'spotfin-butterflyfish.html',
 'belted-cardinalfish.html',
 'blackfin-cardinalfish.html',
 'flamefish.html',
 'dusky-cardinalfish.html',
 'chub.html',
 'clingfish_gallery.html',
 'beaugregory.html',
 'bi-colored-damselfish.html',
 'chromis.html',
 'chromis.html',
 'cocoa-damselfish.html',
 'dusky-damselfish.html',
 'longfin-damselfish.html',
 'night-sergeant.html',
 'threespot-damselfish.html',
 'sergeant-major.html',
 'yellowtail-damselfish.html',
 'spotted-drum.html',
 'highhat.html',
 'mutton-snapper.html',
 'schoolmaster-snapper.html',
 'yellowtail-snapper.html',
 'common-snook.html',
 'blackbar-soldierfish.html',
 'common-squirrelfish.html',
 'dusky-squirrelfish.html',
 'longspine-squirrelfish.html',
 'reef-squirrelfish.html',
 'southern-stingray.html',
 'blue-tang.html',
 'doctorfish.html',
 'surgeonfish.html',
 'glassy-sweeper.html',
 'tarpon.html',
 'queen-triggerfish.html',
 'sand-tilefish.html',
 'trumpetfish.html',
 'buffalo-trunkfish.html',
 'smooth-trunkfish.html',
 'spotted-trunkfish.html',
 'blackear-wrasse.html',
 'bluehead-wrasse.html',
 'clown-wrasse.html',
 'creole-wrasse.html',
 'green-razorfish.html',
 'pearly-razorfish.html',
 'puddingwife.html',
 'rosy-razorfish.html',
 'slippery-dick-wrasse.html',
 'spanish-hogfish.html',
 'yellowhead-wrasse.html']

# %% [markdown]
# Okay, this should get us started at least.

# %%
STJ_page_prefix = 'https://www.snorkelstj.com/'
test_species_suffix = 'shortfin-pipefish.html'
page = requests.get(STJ_page_prefix+test_species_suffix)

test_STJ_soup = BeautifulSoup(page.content, "html.parser")

# %%
test_content = test_STJ_soup.find('section',{'id':'content'})

# %%
test_content.find('span',{'class':'auto-style2'}).get_text()
# Out:
# 'Cosmocampus elucens'

# %%
test_content.find_all('span',{'class':'Italic'})[0].get_text() in fish_DF.scientific_name.values
# Out:
# True

# %% [markdown]
# Okay, the check is easy enough. Now just get the images and put them in the correct folder. First let's add the stj_hrefs to our fish_DF. We will do this by accessing all the pages, checking if the species is in our DF, and then storing it if yes.

# %%
STJ_page_prefix = 'https://www.snorkelstj.com/'

fish_DF['stj_href'] = pd.Series(dtype = 'object')
STJ_scientific_names = []
for STJ_href in STJ_hrefs:
    page = requests.get(STJ_page_prefix+STJ_href)
    soup = BeautifulSoup(page.content, "html.parser")
    content = soup.find('section',{'id':'content'})
    if STJ_href == 'unicorn-filefish.html':
        species_scientific = content.find('span',{'class':'auto-style3'}).get_text()
    elif STJ_href == 'shortfin-pipefish.html':
        species_scientific = content.find('span',{'class':'auto-style2'}).get_text()
    else:
        species_scientific = content.find('span',{'class':'Italic'}).get_text()

    second_species = None
    if '(' in species_scientific:
        species_scientific = species_scientific.split('(')[1].replace(')','')
    elif '/' in species_scientific:
        halves = species_scientific.split('/')
        halves[0] = halves[0].strip()
        genus = halves[0].split()[0]
        species = halves[0].split()[1]
        species_scientific = genus + ' ' + species
        if len(halves[1].split()) == 1:
            second_species = genus + ' ' + halves[1].strip()
        else:
            second_species = halves[1].strip()
    elif '-' in species_scientific:
        species_scientific = species_scientific.split('-')[1]
    elif '\xa0' in species_scientific:
        species_scientific = species_scientific.split('\xa0')[0]
    elif ',' in species_scientific:
        halves = species_scientific.split(',')
        species_scientific = halves[0]
        second_species = halves[1].strip()
        
    species_scientific = species_scientific.replace('\t','').replace('\n','').replace('\r','')
    species_scientific = species_scientific.replace('Most likely: ','')
    species_scientific = species_scientific.strip()    
    STJ_scientific_names.append(species_scientific)
    if second_species != None:
        STJ_scientific_names.append(second_species)

    if species_scientific in fish_DF.scientific_name.values:
        fish_DF.stj_href.loc[fish_DF.scientific_name == species_scientific] = STJ_href
    if (second_species != None) and (second_species in fish_DF.scientific_name.values):
        fish_DF.stj_href.loc[fish_DF.scientific_name == second_species] = STJ_href

    # check for common name match but keep current href if already found by scientific name
    common_name = ' '.join(STJ_href.replace('.html','').split('-'))
    common_name = ' '.join([text.capitalize() for text in common_name.split()])
    if (common_name in fish_DF.common_name.values) and (fish_DF.stj_href.loc[fish_DF.common_name == common_name].isnull().values.any()):
        fish_DF.stj_href.loc[fish_DF.common_name == common_name] = STJ_href

# %%
fish_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   scientific_name    263 non-null    object
#  1   scientific_family  263 non-null    object
#  2   common_name        263 non-null    object
#  3   common_family      263 non-null    object
#  4   size_range_cm      263 non-null    object
#  5   depth_range_m      263 non-null    object
#  6   geodist            263 non-null    object
#  7   smithsonian_href   263 non-null    object
#  8   stj_href           152 non-null    object
# dtypes: object(9)
# memory usage: 18.6+ KB

# %% [markdown]
# Yikes.. barely half? Let's look at some scientific names..

# %%
STJ_scientific_names
# Out:
# ['Pomacanthus paru',
#  'Pomacanthus arcuatus',
#  'Holacanthus ciliaris',
#  'Holacanthus tricolor',
#  'Sphyraena barracuda',
#  'Gramma loreto',
#  'Serranus tigrinus',
#  'Ogcocephalus nasutus',
#  'Malacoctenus versicolor',
#  'Malacoctenus gilli',
#  'Malacoctenus aurolineatus',
#  'Labrisomus nuchipinnis',
#  'Labrisomus guppyi',
#  'Scartella cristata',
#  'Hypleurochilus springeri',
#  'Entomacrodus nigricans',
#  'Labrisomus bucciferus',
#  'Ophioblennius macclurei',
#  'Malacoctenus macropus',
#  'Enneanectes spp.',
#  'Malacoctenus triangulatus',
#  'Parablennius marmoreus',
#  'Acanthemblemaria maria',
#  'Acanthemblemaria spinosa',
#  'Labrisomus nigricinctus',
#  'Coralliozetus cardonae',
#  'Albula vulpes',
#  'Acanthostracion polygonia',
#  'Acanthostracion quadricornis',
#  'Chaetodon striatus',
#  'Chaetodon capistratus',
#  'Chaetodon ocellatus',
#  'Apogon townsendi',
#  'Apogon binotatus',
#  'Astrapogon puncticulatus',
#  'Apogon maculatus',
#  'Phaeoptyx pigmentaria',
#  'Kyphosus sectatrix',
#  'Kyphosus incisor',
#  'Arcos macrophthalmus',
#  'Stegastes leucostictus',
#  'Stegastes partitus',
#  'Azurina cyanea',
#  'Chromis multilineata',
#  'Azurina cyanea',
#  'Chromis multilineata',
#  'Stegastes veriabilis',
#  'Stegastes adustus',
#  'Stegastes diencaeus',
#  'Abudefduf taurus',
#  'Stegastes planifrons',
#  'Abudefduf saxatilis',
#  'Microspathodon chrysurus',
#  'Eques punctatus',
#  'Pareques acuminatus',
#  'Odontoscion dentex',
#  'Heteroconger longissimus',
#  'Echidna catenata',
#  'Enchelycore carychroa',
#  'Gymnothorax miliaris',
#  'Myrichthys ocellatus',
#  'Gymnothorax funebris',
#  'Gymnothorax vicinus',
#  'Gymnothorax moringa',
#  'Cantherhines pullus',
#  'Aluterus scriptus',
#  'Monacanthus tuckeri',
#  'Cantherhines macrocerus',
#  'Aluterus monoceros',
#  'Bothus lunatus',
#  'Pseudupeneus maculatis',
#  'Pseudupeneus maculatus',
#  'Elacatinus genie',
#  'Coryphopterus dicrus',
#  'Coryphopterus glaucofraenum',
#  'Ctenogobius saepepallens',
#  'Bathygobius soporator',
#  'Coryphopterus personatus',
#  'Coryphopterus hyalinus',
#  'Gnatholepis thompsoni',
#  'Elacatinus multifasciatum',
#  'Coryphopterus personatus',
#  'Coryphopterus hyalinus',
#  'Ginsburgellus novemlineatus',
#  'Mycteroperca bonaci',
#  'Cephalopholis fulva',
#  'Cephalopholis cruentatus',
#  'Rypticus saponaceus',
#  'Alphestes afer',
#  'Epinephelus striatus',
#  'Epinephelus guttatus',
#  'Epinephelus adscensionis',
#  'Serranus tabacarius',
#  'Dectylopterus volitans',
#  'Anisotremus surinamensis',
#  'Haemulon sciurus',
#  'Haemulon carbonarium',
#  'Haemulon flavolineatum',
#  'Anisotremus virginicus',
#  'Haemulon parra',
#  'Haemulon chrysargyreum',
#  'Haemulon macrostomum',
#  'Haemulon aurolinaeatum',
#  'Haemulon album',
#  'Haemulon plumierii',
#  'Hypoplectrus sp.',
#  'Hypoplectrus puella',
#  'Hypoplectrus sp.',
#  'Hypoplectrus unicolor',
#  'Hypoplectrus indigo',
#  'Alphestes afer',
#  'Hypoplectrus randallorum',
#  'Hypoplectrus sp.',
#  'Hypoplectrus chlorurus',
#  'ypoplectrus sp.',
#  'Harengula humerali',
#  'Seriola rivoliana',
#  'Caranx ruber',
#  'Selar crumenophthalmus',
#  'Caranx crysos',
#  'Caranx latus',
#  'Oligoplites saurus',
#  'Trachinotus goodei',
#  'Trachinotus falcatus',
#  'Caranx bartholomaei',
#  'Opistognathus macrognathus',
#  'Opistognathus maxillosus',
#  'Opistognathus aurifrons',
#  'Pterois volitans',
#  'Synodus intermedius',
#  'Synodus foetens',
#  'Scomberomorus regalis',
#  'Anisotremus surinamensis',
#  'Haemulon album',
#  'Eucinostomus melanopterus',
#  'Eucinostomus lefroyi',
#  'Gerres cinereus',
#  'Mugil curema',
#  'Ablennes hians',
#  'Hemiramphus brasiliensis',
#  'Sparisoma radians',
#  'Scarus taeniopterus',
#  'Scarus vetula',
#  'Scarus guacamaia',
#  'Sparisoma aurofrenatum',
#  'Sparisoma rubripinne',
#  'Sparisoma viride',
#  'Scarus iserti',
#  'Micrognathus crinitus',
#  'Cosmocampus elucens',
#  'Diodon holocanthus',
#  'Chilomycterus antennatus',
#  'Diodon hystrix',
#  'Archosargus rhomboidalis',
#  'Calamus penna',
#  'Diplodus argenteus',
#  'Sphoeroides spengleri',
#  'Sphoeroides testudineus',
#  'Canthigaster rostrata',
#  'Dasyatis americana',
#  'Aetobatus narinari',
#  'Echeneis naucrates',
#  'Scorpaena grandicornis',
#  'Scorpaenodes caribbaeus',
#  'Scorpaena plumieri',
#  'Carcharhinus limbatus',
#  'Negaprion brevirostris',
#  'Ginglymostoma cirratum',
#  'Lutjanus cyanopterus',
#  'Lutjanus jocu',
#  'Heteropriacanthus cruentatus',
#  'Lutjanus griseus',
#  'Lutjanus synagris',
#  'Lutjanus mahogoni',
#  'Lutjanus analis',
#  'Lutjanus apodus',
#  'Ocyurus chrysurus',
#  'Centropomus undecimalis',
#  'Myripristis jacobus',
#  'Holocentrus adscensionis',
#  'Sargocentron vexillarium',
#  'Holocentrus rufus',
#  'Sargocentron coruscum',
#  'Dasyatis americana',
#  'Acanthurus coeruleus',
#  'Acanthurus chirurgus',
#  'Acanthurus tractus',
#  'Pempheris schomburgki',
#  'Megalops atlanticus',
#  'Balistes vetula',
#  'Malacanthus plumieri',
#  'Aulostomus maculatus',
#  'Lactophrys trigonus',
#  'Lactophrys triqueter',
#  'Lactophrys bicaudalis',
#  'Halichoeres poeyi',
#  'Thalassoma bifasciatum',
#  'Halichoeres maculipinna',
#  'Bodianus parrae',
#  'Xyrichtys splendens',
#  'Xyrichtys novacula',
#  'Halichoeres radiatus',
#  'Xyrichtys martinicensis',
#  'Halichoeres bivittatus',
#  'Bodianus rufus',
#  'Halichoeres garnoti']

# %%
len(STJ_scientific_names)
# Out:
# 206

# %% [markdown]
# Alright so we know that we will be short at least ~60.. There are a lot that contained weird characters for some reason, so we cleaned those up Also there are a few pages that seem to be for multiple species that arent getting picked up well. So we split them up into individual species and dealt with those. Unfortunately, a lot of them are like 'Hypoplectrus sp.' which is really unhelpful. We could try and match by the common name as well... perhaps we can look for a common name match by extracting the common name from the href. Doing an exact match by common name netted us a dozen more references.. not bad. The two things left for improvement are: fuzzy matching by common name, and looking up scientific name inconsistencies or mistakes as we did for the smithsonian database. Seeing as I don't want to do that right now and we can only improve by about 50 species, we are going to move on.

# %%
def stj_scrape(scientific_name,scientific_family,stj_href,download_flag):
    ### This function takes in the end of a URL and uses it to access the appropriate webpage on reefguide.org
    ### For example, being passed 'french-angelfish.html' will access the URL 'https://www.snorkelstj.com/french-angelfish.html'
    ### It will then collect the desired species information from the web page as well as download all the images
    ### If the download flag is boolean True using the function reefguide_images and store them in the appropriate folder
    ### on my HDD.

    # Get page HTML

    stj_prefix = 'https://www.snorkelstj.com/'
    species_URL = stj_prefix + stj_href
    species_page = requests.get(species_URL)
    species_soup = BeautifulSoup(species_page.content, "html.parser")
    
    # Get Img Links

    content = species_soup.find('section',{'id':'content'})
    img_link_suffixes = content.find_all('img')

    if download_flag:
        stj_download(img_link_suffixes, scientific_family, scientific_name)
    else:
        pass

    return

def stj_download(img_link_suffixes,scientific_family,scientific_name):
    ### This function downloads all images from the species page and stores them in a species labelled folder on my HDD
    ### The folder is named for the scientific name as well as fits into the scientific family heirarchy
    ### The function will separate images into different folders based on labels such as juvenile, initial

    stj_pix_prefix = 'https://www.snorkelstj.com/'

    for html_suffix in img_link_suffixes:

        # Get Image URL and image data

        suffix = html_suffix.get('src')
        img_link = stj_pix_prefix + suffix
        img_data = requests.get(img_link).content

        # Construct save path

        path_prefix = 'E:/LargeDatasets/SpeciesID-Images/'
        folder_path = path_prefix + scientific_family + '/' + scientific_name.replace(' ','_') + '_'
        filename = suffix.split('/')[-1]
        img_path = folder_path + '/' + filename
        img_path = img_path.replace('\r','').replace('\n','')

        # check if path exists and if not make it so

        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # check if file already exists and if so skip

        if os.path.exists(img_path):
            continue
        
        with open(img_path, 'wb') as handler:
            handler.write(img_data)

    return

# %%
fish_DF.stj_href.loc[fish_DF.common_name == 'Freckled Soapfish']
# Out:
# 1    NaN
# Name: stj_href, dtype: object

# %%
fish_DF.stj_href.loc[fish_DF.common_name == 'Freckled Soapfish'].isnull().values.any()
# Out:
# True

# %%
fish_DF.loc[fish_DF.stj_href.isnull() == False][:2]
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 2        Apogon binotatus        Apogonidae  Barred Cardinalfish
#
#     common_family size_range_cm depth_range_m  \
# 0         Wrasses  (12.0, 20.0)   (2.0, 12.0)
# 2  Cardinalfishes   (0.0, 10.0)   (1.0, 45.0)
#
#                                              geodist smithsonian_href  \
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...         spe/3894
# 2                [Caribbean, Bahamas, South Florida]         spe/3595
#
#                     stj_href
# 0  slippery-dick-wrasse.html
# 2   belted-cardinalfish.html

# %%
fish_DF.loc[fish_DF.stj_href.isnull() == False].apply(lambda x: stj_scrape(x.scientific_name, x.scientific_family, x.stj_href,1), axis = 1)
# Out:
# 0      None
# 2      None
# 3      None
# 4      None
# 6      None
#        ...
# 250    None
# 251    None
# 257    None
# 261    None
# 262    None
# Length: 152, dtype: object

# %% [markdown]
# Nice! Now let's save the fish_DF with the stj_hrefs column added

# %%
fish_DF.to_pickle('./files/fishspecies_reefguide_info_3.pkl')

# %%
fish_DF = pd.read_pickle('./files/fishspecies_reefguide_info_3.pkl')

# %%
fish_DF.head()
# Out:
#           scientific_name scientific_family          common_name  \
# 0  Halichoeres bivittatus          Labridae        Slippery Dick
# 1   Rypticus bistrispinus        Serranidae    Freckled Soapfish
# 2        Apogon binotatus        Apogonidae  Barred Cardinalfish
# 3       Lutjanus mahogoni        Lutjanidae     Mahogany Snapper
# 4       Lutjanus synagris        Lutjanidae         Lane Snapper
#
#     common_family size_range_cm depth_range_m  \
# 0         Wrasses  (12.0, 20.0)   (2.0, 12.0)
# 1      Soapfishes   (7.5, 13.0)   (3.0, 21.0)
# 2  Cardinalfishes   (0.0, 10.0)   (1.0, 45.0)
# 3        Snappers  (18.0, 30.0)   (6.0, 18.0)
# 4        Snappers  (20.0, 30.0)   (2.0, 40.0)
#
#                                              geodist smithsonian_href  \
# 0  [Caribbean, Bahamas, Florida, Bermuda, Gulf of...         spe/3894
# 1        [Caribbean, Bahamas, South Florida, Brazil]         spe/3537
# 2                [Caribbean, Bahamas, South Florida]         spe/3595
# 3      [Caribbean, Bahamas, Florida, Gulf of Mexico]         spe/3690
# 4  [Caribbean, Bahamas, Florida, Gulf of Mexico, ...         spe/3692
#
#                     stj_href
# 0  slippery-dick-wrasse.html
# 1                        NaN
# 2   belted-cardinalfish.html
# 3      mahogany-snapper.html
# 4          lane-snapper.html
